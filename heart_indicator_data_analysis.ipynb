# %% [markdown]
# # <b> EDA on 2022 annual CDC survey data of 400k+ adults related to their health status.

# %% [markdown]
# ### **Contributers:**
#
# - Ali Bin Kashif : [Know about Ali here.](https://www.linkedin.com/in/ali-bin-kashif/)
# - Muhammad Aman : [Know about Aman here.](https://www.linkedin.com/in/muhammad-aman-5a9317288/)

# %% [markdown]
# ### <b>About Dataset:</b>
#
# According to the CDC, heart disease is a leading cause of death for people of most races in the U.S. (African Americans, American Indians and Alaska Natives, and whites). About half of all Americans (47%) have at least 1 of 3 major risk factors for heart disease: high blood pressure, high cholesterol, and smoking. Other key indicators include diabetes status, obesity (high BMI), not getting enough physical activity, or drinking too much alcohol. Identifying and preventing the factors that have the greatest impact on heart disease is very important in healthcare. In turn, developments in computing allow the application of machine learning methods to detect "patterns" in the data that can predict a patient's condition.
#
# The dataset originally comes from the CDC and is a major part of the Behavioral Risk Factor Surveillance System (BRFSS), which conducts annual telephone surveys to collect data on the health status of U.S. residents. As described by the CDC: "Established in 1984 with 15 states, BRFSS now collects data in all 50 states, the District of Columbia, and three U.S. territories. BRFSS completes more than 400,000 adult interviews each year, making it the largest continuously conducted health survey system in the world.

# %% [markdown]
# ### **Variables**:
#
# There are 40 variables(columns) in this dataset.
#
# - **State :** The U.S. state where the individual resides.
#
# - **Sex :** Gender of the individual (Male or Female).
#
# - **GeneralHealth :** Self-reported general health status of the individual.
#
# - **PhysicalHealthDays :** Number of days in the past 30 days that physical health was not good.
#
# - **MentalHealthDays :** Number of days in the past 30 days that mental health was not good.
#
# - **LastCheckupTime :** Time since the last routine checkup or health examination.
#
# - **PhysicalActivities :** Frequency of engaging in physical activities or exercises.
#
# - **SleepHours :** Average number of hours of sleep per night.
#
# - **RemovedTeeth :** Number of permanent teeth removed due to dental issues.
#
# - **HadHeartAttack :** Whether the individual has had a heart attack.
#
# - **HadAngina :** Whether the individual has experienced angina (chest pain or discomfort).
#
# - **HadStroke :** Whether the individual has had a stroke.
#
# - **HadAsthma :** Whether the individual has had asthma.
#
# - **HadSkinCancer :** Whether the individual has had skin cancer.
#
# - **HadCOPD :** Whether the individual has had Chronic Obstructive Pulmonary Disease (COPD).
#
# - **HadDepressiveDisorder :** Whether the individual has had a depressive disorder.
#
# - **HadKidneyDisease :** Whether the individual has had kidney disease.
#
# - **HadArthritis :** Whether the individual has had arthritis.
#
# - **HadDiabetes :** Whether the individual has had diabetes.
#
# - **DeafOrHardOfHearing :** Whether the individual is deaf or hard of hearing.
#
# - **BlindOrVisionDifficulty :** Whether the individual has blindness or vision difficulty.
#
# - **DifficultyConcentrating :** Self-reported difficulty in concentrating.
#
# - **DifficultyWalking :** Self-reported difficulty in walking.
#
# - **DifficultyDressingBathing :** Self-reported difficulty in dressing or bathing.
#
# - **DifficultyErrands :** Self-reported difficulty in running errands.
#
# - **SmokerStatus :** Current smoking status of the individual (smoker, former smoker, non-smoker).
#
# - **ECigaretteUsage :** Whether the individual uses e-cigarettes.
#
# - **ChestScan :** Whether the individual has had a chest scan.
#
# - **RaceEthnicityCategory :** Categorized race or ethnicity of the individual.
#
# - **AgeCategory :** Categorized age group of the individual.
#
# - **HeightInMeters :** Height of the individual in meters.
#
# - **WeightInKilograms :** Weight of the individual in kilograms.
#
# - **BMI :** Body Mass Index calculated from height and weight.
#
# - **AlcoholDrinkers :** Whether the individual consumes alcohol.
#
# - **HIVTesting :** Whether the individual has undergone HIV testing.
#
# - **FluVaxLast12 :** Whether the individual received a flu vaccine in the last 12 months.
#
# - **PneumoVaxEver :** Whether the individual has ever received a pneumonia vaccine.
#
# - **TetanusLast10Tdap :** Time since the last tetanus vaccination (in the last 10 years, received Tdap).
#
# - **HighRiskLastYear :** Whether the individual has been considered at high risk for the past year.
#
# - **CovidPos :** Whether the individual tested positive for COVID-19.

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# ### **Understanding and Mitigating Cardiovascular Health Disparities:** An In-Depth Analysis of Risk Factors and Health Behaviors in the Adult Population.
#
# The problem centers on identifying and understanding the factors that exert the most significant influence on heart disease prevalence.This exploration is crucial for healthcare initiatives and interventions aimed at prevention and management. The dataset encompasses a range of variables, including demographic information, health behaviors, chronic conditions, and COVID-19 status, providing a rich source for uncovering patterns, correlations, and disparities in cardiovascular health.
#
# We're looking at big questions like what things make heart problems more likely, how mental and physical health are linked, what habits and steps help prevent heart issues, how other health problems affect the heart, and if issues like hearing or vision problems are connected to heart disease. We're also checking how smoking and e-cigarettes are used and how COVID-19 affects heart health.
#
# Our main goal is to extract actionable insights from this wealth of data. We want to make plans that focus on specific things to help reduce differences in heart health and make everyone's heart healthier in the adult population.

# %% [markdown]
# # Research and Analytical Questions:

# %% [markdown]
# These research questions are given by ChatGPT according to our problem statement.
#
# **Demographic Variation:**
#
# - How does the prevalence of heart disease and major risk factors vary across different demographic groups (sex, age, race/ethnicity)?
# Are there specific subgroups experiencing higher cardiovascular health disparities?
# Risk Factor Patterns:
#
# - What are the common patterns and combinations of major risk factors (high blood pressure, high cholesterol, smoking) within the dataset?
# How do these patterns relate to the overall cardiovascular health of individuals?
#
# **Impact of Chronic Conditions:**
#
# - Among individuals with chronic conditions (diabetes, asthma, COPD), how does the presence of these conditions correlate with heart disease prevalence?
# - Are certain chronic conditions more strongly associated with cardiovascular health disparities?
#
# **Behavioral Correlations:**
#
# - Explore the relationships between health behaviors (physical activity, sleep, alcohol consumption) and the prevalence of heart disease.
# - Identify key behavioral factors that may contribute to cardiovascular health disparities.
#
# **Effect of Mental Health on Heart Disease:**
#
# - Investigate the interplay between mental health (mental health days, depressive disorders) and heart disease.
# - Are individuals with certain mental health conditions more susceptible to cardiovascular issues?
#
# **Sensory Impairments and Cardiovascular Health:**
#
# - Analyze the impact of sensory impairments (deafness, vision difficulties) on heart disease prevalence and risk factors.
# - Explore if difficulty in concentration or physical activities differs based on sensory impairments.
#
# **Impact of COVID-19:**
#
# - Explore the influence of COVID-19 on cardiovascular health, considering its association with heart disease prevalence and related risk factors.
# - Analyze if individuals who tested positive for COVID-19 exhibit distinctive patterns in cardiovascular health.
#
# **Some Other questions:**
# - Can you indicate which variables have a significant effect on the likelihood of heart disease?
# - How many people have at least 1 of 3 major risk factors for heart disease: high blood pressure, high cholesterol, and smoking.

# %% [markdown]
# # Importing Python Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Functions for plot and charts customizations

# %%
# Function for setting style and size of plot
def set_size_style(width, height, style=None):
    plt.figure(figsize=(width, height))
    if style != None:
        sns.set_style(style)

# Function for customizating the plot
def customize_plot(plot, title:str, xlabel:str,  ylabel:str, title_font:int, label_font:int):
    plot.set_title(title, fontsize = title_font, weight='bold')
    plot.set_xlabel(xlabel, fontsize = label_font, weight='bold')
    plot.set_ylabel(ylabel, fontsize = label_font, weight='bold')

# %% [markdown]
# # Loading dataset

# %%
# Extract the given zip file if csv file is not present in the dataset folder
heart_data = pd.read_csv('./dataset/heart_2022_with_nans.csv' ,encoding='unicode_escape')

# %% [markdown]
# # Data Identification and Cleaning

# %%
heart_data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %%
heart_data.shape
# Out:
# (445132, 40)

# %% [markdown]
# - There are 445132 rows and 40 columns in the dataset.

# %%
heart_data.tail()
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 445127  Virgin Islands  Female          Good                 0.0
# 445128  Virgin Islands  Female     Excellent                 2.0
# 445129  Virgin Islands  Female          Poor                30.0
# 445130  Virgin Islands    Male     Very good                 0.0
# 445131  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 445127               3.0  Within past 2 years (1 year but less than 2 ye...
# 445128               2.0  Within past year (anytime less than 12 months ...
# 445129              30.0                                5 or more years ago
# 445130               0.0  Within past year (anytime less than 12 months ...
# 445131               1.0                                                NaN
#
#        PhysicalActivities  SleepHours  RemovedTeeth HadHeartAttack  ...  \
# ...

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      445132 non-null  object
#  1   Sex                        445132 non-null  object
#  2   GeneralHealth              443934 non-null  object
#  3   PhysicalHealthDays         434205 non-null  float64
#  4   MentalHealthDays           436065 non-null  float64
#  5   LastCheckupTime            436824 non-null  object
#  6   PhysicalActivities         444039 non-null  object
#  7   SleepHours                 439679 non-null  float64
#  8   RemovedTeeth               433772 non-null  object
#  9   HadHeartAttack             442067 non-null  object
#  10  HadAngina                  440727 non-null  object
#  11  HadStroke                  443575 non-null  object
#  12  HadAsthma                  443359 non-null  object
# ...

# %% [markdown]
# - Most of the columns(variables) are categorical and boolen.
# - Physical and mental health days, sleep hours, height, weight, BMI are numeric(float) values.

# %% [markdown]
# ### Handling null values

# %%
heart_data.isna().sum()
# Out:
# State                            0
# Sex                              0
# GeneralHealth                 1198
# PhysicalHealthDays           10927
# MentalHealthDays              9067
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                    5453
# RemovedTeeth                 11360
# HadHeartAttack                3065
# HadAngina                     4405
# HadStroke                     1557
# HadAsthma                     1773
# HadSkinCancer                 3143
# HadCOPD                       2219
# HadDepressiveDisorder         2812
# HadKidneyDisease              1926
# HadArthritis                  2633
# HadDiabetes                   1087
# DeafOrHardOfHearing          20647
# BlindOrVisionDifficulty      21564
# DifficultyConcentrating      24240
# DifficultyWalking            24012
# DifficultyDressingBathing    23915
# DifficultyErrands            25656
# SmokerStatus                 35462
# ECigaretteUsage              35660
# ...

# %%
set_size_style(8,10,'whitegrid')
heart_data.isna().sum().plot(kind='barh')
# Out:
# <Axes: >

# %%
# Calculating percentage of null values in each column
null_values = round(heart_data.isna().sum()/heart_data.shape[0] * 100,2)

# %%
null_values
# Out:
# State                         0.00
# Sex                           0.00
# GeneralHealth                 0.27
# PhysicalHealthDays            2.45
# MentalHealthDays              2.04
# LastCheckupTime               1.87
# PhysicalActivities            0.25
# SleepHours                    1.23
# RemovedTeeth                  2.55
# HadHeartAttack                0.69
# HadAngina                     0.99
# HadStroke                     0.35
# HadAsthma                     0.40
# HadSkinCancer                 0.71
# HadCOPD                       0.50
# HadDepressiveDisorder         0.63
# HadKidneyDisease              0.43
# HadArthritis                  0.59
# HadDiabetes                   0.24
# DeafOrHardOfHearing           4.64
# BlindOrVisionDifficulty       4.84
# DifficultyConcentrating       5.45
# DifficultyWalking             5.39
# DifficultyDressingBathing     5.37
# DifficultyErrands             5.76
# SmokerStatus                  7.97
# ECigaretteUsage               8.01
# ...

# %%
# Dropping columns which we don't need.

heart_data = heart_data.drop(columns=['State', 'RemovedTeeth', 'LastCheckupTime', 'ChestScan', 'HIVTesting', 'FluVaxLast12', 'PneumoVaxEver', 'TetanusLast10Tdap', 'HighRiskLastYear'])

# %%
heart_data.columns
# Out:
# Index(['Sex', 'GeneralHealth', 'PhysicalHealthDays', 'MentalHealthDays',
#        'PhysicalActivities', 'SleepHours', 'HadHeartAttack', 'HadAngina',
#        'HadStroke', 'HadAsthma', 'HadSkinCancer', 'HadCOPD',
#        'HadDepressiveDisorder', 'HadKidneyDisease', 'HadArthritis',
#        'HadDiabetes', 'DeafOrHardOfHearing', 'BlindOrVisionDifficulty',
#        'DifficultyConcentrating', 'DifficultyWalking',
#        'DifficultyDressingBathing', 'DifficultyErrands', 'SmokerStatus',
#        'ECigaretteUsage', 'RaceEthnicityCategory', 'AgeCategory',
#        'HeightInMeters', 'WeightInKilograms', 'BMI', 'AlcoholDrinkers',
#        'CovidPos'],
#       dtype='object')

# %%
heart_data = heart_data.dropna( subset=['HadHeartAttack'] )
heart_data.shape
heart_data
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0       Female     Very good                 0.0               0.0
# 1       Female     Excellent                 0.0               0.0
# 2       Female     Very good                 2.0               3.0
# 3       Female     Excellent                 0.0               0.0
# 4       Female          Fair                 2.0               0.0
# ...        ...           ...                 ...               ...
# 445127  Female          Good                 0.0               3.0
# 445128  Female     Excellent                 2.0               2.0
# 445129  Female          Poor                30.0              30.0
# 445130    Male     Very good                 0.0               0.0
# 445131    Male     Very good                 0.0               1.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 0                      No         8.0             No        No        No
# ...

# %% [markdown]
# - Not removing more null values, as different columns have null values on different places, so removing a row based on a null value of a specific column can lead to loss of useful values in other columns.

# %%
heart_data.describe(include='object')
# Out:
#            Sex GeneralHealth PhysicalActivities HadHeartAttack HadAngina  \
# count   442067        440972             441095         442067    438479
# unique       2             5                  2              2         2
# top     Female     Very good                Yes             No        No
# freq    234519        147967             335778         416959    412331
#
#        HadStroke HadAsthma HadSkinCancer HadCOPD HadDepressiveDisorder  ...  \
# count     440997    440630        439303  440229                439646  ...
# unique         2         2             2       2                     2  ...
# top           No        No            No      No                    No  ...
# freq      422101    374481        404040  405062                348921  ...
#
#        DifficultyConcentrating DifficultyWalking DifficultyDressingBathing  \
# count                   418272            418463                    418554
# ...

# %%
for col in heart_data.describe(include='object').columns:
    print('Column Name: ',col)
    print(heart_data[col].unique())
    print('-'*50)
# Out:
# Column Name:  Sex
# ['Female' 'Male']
# --------------------------------------------------
# Column Name:  GeneralHealth
# ['Very good' 'Excellent' 'Fair' 'Poor' 'Good' nan]
# --------------------------------------------------
# Column Name:  PhysicalActivities
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadHeartAttack
# ['No' 'Yes']
# --------------------------------------------------
# Column Name:  HadAngina
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadStroke
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadAsthma
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadSkinCancer
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadCOPD
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadDepressiveDisorder
# ['No' 'Yes' nan]
# ...

# %% [markdown]
# - Some columns have large categorical text values, so need to make it short but understandable.

# %%
heart_data['HadDiabetes'].replace({'No, pre-diabetes or borderline diabetes' : 'Borderline', 'Yes, but only during pregnancy (female)' : 'During Pregnancy'} , inplace=True)

heart_data['HadDiabetes'].unique()
# Out:
# array(['Yes', 'No', 'Borderline', nan, 'During Pregnancy'], dtype=object)

# %%
heart_data['SmokerStatus'].replace({'Current smoker - now smokes some days' : 'Current smoker(Some days)',
                                    'Current smoker - now smokes every day' : 'Current smoker(Every day)'}, inplace=True)

heart_data['SmokerStatus'].unique()
# Out:
# array(['Never smoked', 'Current smoker(Some days)', 'Former smoker', nan,
#        'Current smoker(Every day)'], dtype=object)

# %%
heart_data['ECigaretteUsage'].replace({'Not at all (right now)' : 'Not at all',
                                        'Never used e-cigarettes in my entire life' : 'Never',
                                        'Use them every day' : 'Everyday',
                                        'Use them some days' : 'Somedays'}, inplace=True)

heart_data['ECigaretteUsage'].unique()
# Out:
# array(['Not at all', 'Never', nan, 'Everyday', 'Somedays'], dtype=object)

# %%
heart_data['RaceEthnicityCategory'].replace({'White only, Non-Hispanic' : 'White',
                                             'Black only, Non-Hispanic' : 'Black',
                                             'Other race only, Non-Hispanic' : 'Other Race',
                                             'Multiracial, Non-Hispanic' : 'Multi Racial'}, inplace=True)

heart_data['RaceEthnicityCategory'].unique()
# Out:
# array(['White', 'Black', 'Other Race', 'Multi Racial', nan, 'Hispanic'],
#       dtype=object)

# %%
heart_data['AgeCategory'].replace({'Age 80 or older' : '80+'}, inplace=True)

for value in heart_data['AgeCategory'].unique()[1:]:
    value = str(value)
    if value != 'nan':
        cat_value = value.split(" ")
        heart_data['AgeCategory'].replace({value : cat_value[1]+"-"+cat_value[3]}, inplace=True)
        
heart_data['AgeCategory'].unique()
# Out:
# array(['80+', '55-59', nan, '40-44', '75-79', '70-74', '65-69', '60-64',
#        '50-54', '45-49', '35-39', '25-29', '30-34', '18-24'], dtype=object)

# %%
heart_data['CovidPos'].replace({'Tested positive using home test without a health professional' : 'Yes'}, inplace=True)

heart_data['CovidPos'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %% [markdown]
# - Now all categorical values are shortened and easy to understand.

# %%
heart_data.describe(include='object')
# Out:
#            Sex GeneralHealth PhysicalActivities HadHeartAttack HadAngina  \
# count   442067        440972             441095         442067    438479
# unique       2             5                  2              2         2
# top     Female     Very good                Yes             No        No
# freq    234519        147967             335778         416959    412331
#
#        HadStroke HadAsthma HadSkinCancer HadCOPD HadDepressiveDisorder  ...  \
# count     440997    440630        439303  440229                439646  ...
# unique         2         2             2       2                     2  ...
# top           No        No            No      No                    No  ...
# freq      422101    374481        404040  405062                348921  ...
#
#        DifficultyConcentrating DifficultyWalking DifficultyDressingBathing  \
# count                   418272            418463                    418554
# ...

# %% [markdown]
# ### Dropping duplicate rows

# %%
heart_data[heart_data.duplicated()]
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 7310      Male     Very good                 0.0               0.0
# 7971    Female     Very good                 0.0               0.0
# 8049    Female     Very good                 0.0               0.0
# 8178      Male     Excellent                 0.0               0.0
# 11503   Female     Excellent                 0.0               0.0
# ...        ...           ...                 ...               ...
# 444837    Male     Excellent                 0.0               0.0
# 444935  Female     Excellent                 0.0               0.0
# 445009    Male     Excellent                 0.0               0.0
# 445041    Male     Very good                 0.0               0.0
# 445056    Male          Good                 0.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 7310                  Yes         7.0             No        No        No
# ...

# %%
heart_data.drop_duplicates(inplace=True)

# %% [markdown]
# ### Checking columns with numeric data and handling outliers.

# %%
# Display brief summary statistics
heart_data.describe()
# Out:
#        PhysicalHealthDays  MentalHealthDays     SleepHours  HeightInMeters  \
# count       425443.000000     427250.000000  430853.000000   411363.000000
# mean             4.383092          4.431127       7.019940        1.702627
# std              8.707924          8.414919       1.503855        0.107219
# min              0.000000          0.000000       1.000000        0.910000
# 25%              0.000000          0.000000       6.000000        1.630000
# 50%              0.000000          0.000000       7.000000        1.700000
# 75%              4.000000          5.000000       8.000000        1.780000
# max             30.000000         30.000000      24.000000        2.410000
#
#        WeightInKilograms            BMI
# count      398179.000000  391540.000000
# mean           83.107142      28.543281
# std            21.472883       6.563215
# min            22.680000      12.020000
# 25%            68.040000      24.130000
# 50%            80.740000      27.440000
# ...

# %%
for col in heart_data.describe().columns:
    set_size_style(16,2,'ticks')
    sns.boxplot(data=heart_data, x=col)
    plt.show()

# %% [markdown]
# - We will have a closer view of outlier values of height, weight and sleep hours as some values don't looks normal.

# %%
# Function for extracting outliers in column of dataframe
def get_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3-Q1
    
    lower_limit = Q1 - (IQR * 1.5)
    upper_limit = Q3 + (IQR * 1.5)
    
    outliers = df[(df[column] < lower_limit) | (df[column] > upper_limit)]
    
    return outliers, lower_limit, upper_limit

# %%
sleep_hours_outliers, lower_sleep, upper_sleep = get_outliers(heart_data, 'SleepHours')
sleep_hours_outliers
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 88      Female     Excellent                 0.0               0.0
# 95        Male          Poor                 NaN               0.0
# 118     Female          Poor                30.0              30.0
# 127       Male     Very good                 0.0               2.0
# 208     Female          Poor                25.0               0.0
# ...        ...           ...                 ...               ...
# 444948  Female          Fair                 2.0               1.0
# 445066    Male     Very good                 NaN               0.0
# 445103  Female          Good                10.0               0.0
# 445108  Female          Good                 5.0               NaN
# 445113  Female          Good                 0.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 88                     No         1.0             No        No        No
# ...

# %%
print(f"Lower Limit(SleepHours):{lower_sleep})\nUpper Limit(SleepHours):{upper_sleep})")
# Out:
# Lower Limit(SleepHours):3.0)
# Upper Limit(SleepHours):11.0)

# %% [markdown]
# - The Upper Limit of SleepHours is questionnable so we will adjust this according to our own assumption

# %%
heart_data[heart_data['SleepHours'] < lower_sleep]
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 88      Female     Excellent                 0.0               0.0
# 429       Male          Poor                10.0               4.0
# 890     Female          Fair                 NaN               5.0
# 935       Male          Good                 5.0               0.0
# 1228      Male     Excellent                 4.0              14.0
# ...        ...           ...                 ...               ...
# 444551  Female          Fair                25.0              10.0
# 444600  Female          Poor                 7.0               7.0
# 444617    Male     Excellent                 0.0               0.0
# 444797  Female          Fair                 1.0               0.0
# 444907  Female     Excellent                10.0              10.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 88                     No         1.0             No        No        No
# ...

# %%
heart_data[heart_data['SleepHours'] > 13]
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 118     Female          Poor                30.0              30.0
# 623     Female          Fair                 0.0               0.0
# 676     Female          Poor                30.0              10.0
# 1205    Female     Very good                 0.0              15.0
# 1320    Female          Good                15.0              15.0
# ...        ...           ...                 ...               ...
# 444751  Female     Very good                 0.0               0.0
# 444778  Female          Fair                 7.0               0.0
# 444948  Female          Fair                 2.0               1.0
# 445066    Male     Very good                 NaN               0.0
# 445108  Female          Good                 5.0               NaN
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 118                    No        18.0            Yes       Yes       Yes
# ...

# %% [markdown]
# - Dropping rows with outlier values in sleeping hours as data seems incorrect, some people have excellent health condition with sleeping more than 13 hours and also less than 3 hours, that seems to be incorrect readings.

# %%
heart_data.shape
# Out:
# (436040, 31)

# %%
# Dropping records with sleep less than 3 hours
heart_data = heart_data.drop(heart_data[heart_data['SleepHours'] < lower_sleep].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (433407, 31)

# %%
# Dropping record with sleep greater than 16 hourss
heart_data = heart_data.drop(heart_data[heart_data['SleepHours'] > 13].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (432050, 31)

# %%
sns.boxplot(data=heart_data, x='SleepHours')
# Out:
# <Axes: xlabel='SleepHours'>

# %%
height_outliers, lower_height, upper_height = get_outliers(heart_data, 'HeightInMeters')
height_outliers
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 551     Female          Fair                30.0               0.0
# 860     Female          Poor                30.0              30.0
# 887     Female          Fair                30.0               0.0
# 1510      Male          Good                 0.0               0.0
# 1527      Male     Very good                 0.0               0.0
# ...        ...           ...                 ...               ...
# 431634    Male     Very good                 0.0               0.0
# 431660    Male           NaN                 1.0               0.0
# 431783    Male          Poor                30.0              25.0
# 431867  Female          Fair                 0.0               0.0
# 432027  Female          Fair                 0.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 551                    No         6.0            Yes        No       Yes
# ...

# %%
print(f"Lower Limit(Height):{lower_height})\nUpper Limit(Height):{upper_height})")
# Out:
# Lower Limit(Height):1.4049999999999998)
# Upper Limit(Height):2.0050000000000003)

# %% [markdown]
# - The lower limit seems a bit strict because some adults can be shorter than 1.4 meters. Similarly, the upper limit might be too narrow because some people can be taller than 2 meters. We'll change these limits based on our own ideas or assumptions.

# %%
heart_data[heart_data['HeightInMeters'] < 1.3]
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 551     Female          Fair                30.0               0.0
# 860     Female          Poor                30.0              30.0
# 887     Female          Fair                30.0               0.0
# 2341    Female          Good                 0.0               0.0
# 8915      Male          Fair                 0.0               1.0
# ...        ...           ...                 ...               ...
# 427850  Female          Good                14.0              14.0
# 428604  Female          Fair                 0.0               0.0
# 429821  Female          Fair                 0.0               0.0
# 430854  Female          Good                 0.0               0.0
# 431660    Male           NaN                 1.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 551                    No         6.0            Yes        No       Yes
# ...

# %%
heart_data[heart_data['HeightInMeters'] > 2.1]
# Out:
#          Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 5192    Male     Excellent                 0.0               5.0
# 8347    Male     Very good                 0.0               0.0
# 8839    Male          Good                20.0              19.0
# 9487    Male          Good                10.0              15.0
# 22967   Male          Fair                 0.0               0.0
# ...      ...           ...                 ...               ...
# 395252  Male     Very good                 0.0               0.0
# 395411  Male     Excellent                 0.0               0.0
# 399088  Male     Very good                 0.0               0.0
# 423209  Male          Poor                30.0               0.0
# 431634  Male     Very good                 0.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 5192                  Yes         7.0             No        No        No
# ...

# %% [markdown]
# - Dropping rows with outlier values in HeightInMeters as data seems incorrect.

# %%
heart_data.shape
# Out:
# (432050, 31)

# %%
# Dropping records with height less than 1.3 meters
heart_data = heart_data.drop(heart_data[heart_data['HeightInMeters'] < 1.3].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (431790, 31)

# %%
# Dropping records with height greater than 2.1 meters
heart_data = heart_data.drop(heart_data[heart_data['HeightInMeters'] > 2.1].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (431689, 31)

# %%
sns.boxplot(data=heart_data, x='HeightInMeters')
# Out:
# <Axes: xlabel='HeightInMeters'>

# %%
weight_outliers, lower_weight, upper_weight = get_outliers(heart_data, 'WeightInKilograms')
weight_outliers
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 48      Female          Good                 0.0              18.0
# 140     Female          Fair                30.0              20.0
# 156       Male          Good                 0.0               0.0
# 206     Female          Poor                25.0               0.0
# 333     Female          Fair                30.0               8.0
# ...        ...           ...                 ...               ...
# 431254  Female          Good                 0.0               0.0
# 431425    Male          Good                 5.0               0.0
# 431552    Male          Good                 5.0               0.0
# 431572  Female          Good                 2.0               NaN
# 431639  Female          Good                 2.0              10.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 48                     No         8.0             No        No        No
# ...

# %%
print(f"Lower Limit(Weight):{lower_weight})\nUpper Limit(Weight):{upper_weight})")
# Out:
# Lower Limit(Weight):27.225000000000016)
# Upper Limit(Weight):136.065)

# %% [markdown]
# - Again we will adjust the upper limit and lower limit.

# %%
heart_data[heart_data['WeightInKilograms'] < 40]
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 49      Female          Good                 0.0               0.0
# 707     Female          Fair                15.0               7.0
# 794     Female          Fair                30.0              30.0
# 1135    Female          Fair                 NaN               0.0
# 3426    Female          Good                 0.0               0.0
# ...        ...           ...                 ...               ...
# 429418  Female          Fair                28.0               0.0
# 429817  Female          Fair                30.0               0.0
# 431452  Female     Very good                 8.0               4.0
# 431666  Female          Fair                 0.0               0.0
# 431676  Female     Very good                 0.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 49                    Yes         7.0             No       Yes       Yes
# ...

# %%
heart_data[heart_data['WeightInKilograms'] > 200]
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 3098    Female          Fair                 0.0              30.0
# 5869    Female          Fair                30.0               3.0
# 7263      Male          Fair                 5.0              10.0
# 7843      Male          Fair                 2.0              10.0
# 12023   Female     Very good                 0.0               2.0
# ...        ...           ...                 ...               ...
# 417862    Male          Good                 0.0               0.0
# 420908  Female     Very good                 0.0               0.0
# 422143    Male     Very good                 1.0              30.0
# 423472    Male     Very good                 0.0              30.0
# 424021    Male          Good                30.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 3098                   No         6.0             No        No        No
# ...

# %% [markdown]
# - Dropping rows with outlier values in WeightInKilograms as data seems incorrect.

# %%
heart_data.shape
# Out:
# (431689, 31)

# %%
# Dropping records with weight less than 40 kg
heart_data = heart_data.drop(heart_data[heart_data['WeightInKilograms'] < 40].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (431097, 31)

# %%
# Dropping records with weight greater than 200 kg
heart_data = heart_data.drop(heart_data[heart_data['WeightInKilograms'] > 200].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (430828, 31)

# %%
sns.boxplot(data=heart_data, x='WeightInKilograms')
# Out:
# <Axes: xlabel='WeightInKilograms'>

# %% [markdown]
# # <b>Insights from Data</b>

# %% [markdown]
# - Now that the data has been cleaned and prepared, free from any unusual values, and it's ready for analysis. We can start exploring the data to uncover important insights that will help answer our questions.

# %% [markdown]
# ##  Demographic Variation & Risk Factor Patterns:

# %% [markdown]
# - First we are observing the prevalence of heart diseases among different genders.

# %%
gender_count = heart_data['Sex'].value_counts()
gender_count
# Out:
# Sex
# Female    228950
# Male      201878
# Name: count, dtype: int64

# %%
plt.title("Gender Distribution", fontsize = 12, weight='bold')
plt.pie(gender_count,labels=gender_count.index,radius=1, autopct='%.2f%%')
plt.show()

# %% [markdown]
# - Above piechart shows that females are more than males in the sample data population.

# %% [markdown]
# - Now we understand the distribution of ages in this dataset

# %%
set_size_style(10,5,'darkgrid')
ax = sns.countplot(data = heart_data, x = 'AgeCategory', hue='AgeCategory', legend=False)
customize_plot(ax,"Distribution of Age Category","Age Category","Individuals",12,10)
for c in ax.containers:
    ax.bar_label(c)

# %% [markdown]
# - Mostly individuals are aged around 65-69

# %% [markdown]
# - Building on our understanding of demographics, let's explore the prevalence of heart disease among different genders and age groups.

# %%
set_size_style(5,5,'darkgrid')
ax = sns.countplot(data = heart_data, x = 'HadHeartAttack', hue = 'Sex', palette='viridis')
customize_plot(ax,"Prevalence of Heart Attacks Among Different Genders","Had Heart Attack","Individuals",12,10)
for c in ax.containers:
    ax.bar_label(c)

# %% [markdown]
# - Many individuals did not experience any heart disease. However, among those who did, the majority were males.

# %%
set_size_style(12,6,'darkgrid')
ax = sns.countplot(data = heart_data, x = 'AgeCategory', hue = 'HadHeartAttack', palette='viridis')
customize_plot(ax,"Prevalence of Heart Attacks Among Different Age Groups","Had Heart Attack","Individuals",12,10)
for c in ax.containers:
    ax.bar_label(c)

# %% [markdown]
# - The individuals who are above 80 have experienced heart diseases among different age groups. However, those who are aged between 18-24 had a bit of experience with heart diseases

# %% [markdown]
# - Expanding on our examination of demographics, we are now investigating the prevalence of various major risk factors among different genders and age groups.

# %%
heart_data['HadObesity'] = heart_data['BMI'].apply(lambda x: 'Yes' if x >=30 else 'No')

# %% [markdown]
# - The potential risk factors may include 'PhysicalActivities', 'SmokerStatus', 'ECigaretteUsage', 'HadDiabetes', 'HadObesity'

# %%
risk_factors = ['PhysicalActivities', 'SmokerStatus', 'ECigaretteUsage', 'HadDiabetes', 'HadObesity']
set_size_style(15, 12, 'darkgrid')

for i, risk_factor in enumerate(risk_factors, 1):
    plt.subplot(3, 2, i) 
    ax = sns.countplot(data=heart_data, x=risk_factor, hue='Sex', palette='viridis')
    customize_plot(ax, f"{risk_factor} Among Different Genders", risk_factor, "Individuals", 15, 12)
    
    for c in ax.containers:
        ax.bar_label(c)
plt.tight_layout()

# %% [markdown]
# - The majority of individuals engage in physical activities, with females being the most prevalent among them.
# - The majority of individuals have never smoked in their lives. However, males show a slight lead over females in the category of current smokers.
# - Most people never use E-Cigarette. However, majority of the people who regularly use e-cigarettes are males.
# - Most people are not obese. However, among those who are, females are the most.
# - The majority of individuals do not have diabetes. However, among those who do, females constitute the larger portion.

# %%
set_size_style(13, 25, 'darkgrid')

for i, risk_factor in enumerate(risk_factors, 1):
    plt.subplot(5, 1, i) 
    ax = sns.countplot(data=heart_data, x='AgeCategory', hue=risk_factor)
    customize_plot(ax, f"{risk_factor} Among Different Age Groups", "Age Category", "Individuals", 15, 12)
    
    for c in ax.containers:
        ax.bar_label(c)
plt.tight_layout()

# %% [markdown]
# - Most individuals aged around 65-69 are physically active; however, those above 80 exhibit a larger portion of being physically inactive.
# - Most individuals aged between 60 and 64 engage in regular smoking, while those aged 70 to 74 comprise a larger proportion of former smokers.
# - The use of e-cigarettes is popular among individuals aged 18 to 24, as they use e-cigarettes every day more frequently than other age groups.
# - Individuals aged 70 to 74 have a higher proportion of diabetes compared to other age groups. However, individuals between 18 and 30 do not have as much diabetes.
# - People aged 65 to 69 have more obesity compared to other age groups. However, those between 18 and 24 don't have as much obesity.

# %% [markdown]
# - Now let's look at some other common risk factors among different genders and age groups, such as Physical Health Days, Mental Health Days, and Sleep Hours.

# %%
other_risk_factor_among_genders = heart_data.groupby('Sex').agg({'PhysicalHealthDays':'mean', 'MentalHealthDays':'mean', 'SleepHours':'mean'})
other_risk_factor_among_genders
# Out:
#         PhysicalHealthDays  MentalHealthDays  SleepHours
# Sex
# Female            4.674669          5.017051    7.044604
# Male              3.925106          3.668735    6.999585

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, risk_factor in enumerate(other_risk_factor_among_genders.columns, 1):
    plt.subplot(1, 3, i)
    plt.title(f"{risk_factor} among Genders", fontsize = 12, weight='bold')
    plt.pie(other_risk_factor_among_genders[risk_factor], labels=other_risk_factor_among_genders.index, autopct='%1.1f%%', startangle=90)

plt.tight_layout()

# %% [markdown]
# - Females experience a higher percentage of days with poor physical health and poor mental health compared to males. This means that, on average, females report more days of poor physical and mental health in the past 30 days than males.
# - The average number of sleep hours is quite similar between males and females.

# %%
other_risk_factor_among_agegroups = heart_data.groupby('AgeCategory').agg({'PhysicalHealthDays':'mean', 'MentalHealthDays':'mean', 'SleepHours':'mean'})
other_risk_factor_among_agegroups
# Out:
#              PhysicalHealthDays  MentalHealthDays  SleepHours
# AgeCategory
# 18-24                  2.670764          7.621944    7.054182
# 25-29                  2.718131          6.771749    6.934614
# 30-34                  3.002643          6.283092    6.826833
# 35-39                  3.157234          5.722057    6.769582
# 40-44                  3.544787          5.333486    6.801878
# 45-49                  3.991215          5.020162    6.793628
# 50-54                  4.502286          4.817000    6.819462
# 55-59                  5.135147          4.518281    6.871015
# 60-64                  5.280653          3.952635    6.979627
# 65-69                  4.859480          3.185154    7.132100
# 70-74                  4.829594          2.835551    7.231366
# 75-79                  5.129956          2.520005    7.326738
# 80+                    5.351677          2.088589    7.512353

# %%
set_size_style(9, 5, 'darkgrid')
plt.ylabel('Mean Values')
ax =sns.lineplot(data=other_risk_factor_among_agegroups, x='AgeCategory', y='PhysicalHealthDays', label='Physical Health Days')
ax =sns.lineplot(data=other_risk_factor_among_agegroups, x='AgeCategory', y='MentalHealthDays', label='Mental Health Days')
ax= sns.lineplot(data=other_risk_factor_among_agegroups, x='AgeCategory', y='SleepHours', label='Sleep Hours')
plt.legend()
customize_plot(ax,"Risk Factors among Age Groups","Age Groups","Average",12,10)

# %% [markdown]
# - As people get older, they experience more days with poor physical health in the past 30 days. However, as people age, they experience fewer days with poor mental health in the past 30 days.
# - Additionally, older individuals, particularly those aged 65 to 80 and above, tend to sleep slightly more hours.

# %% [markdown]
# # Impact of Chronic Conditions

# %% [markdown]
# - Chronic conditions which we have in our dataset are diabetes, asthma, COPD, skin cancer, arthritis, kidney disease.
# - Some conditions can also be chronic like obesity.

# %%
# Subset necessary columns for the analysis
chronic_diseases = heart_data[['Sex', 'HadHeartAttack', 'HadAngina', 'HadStroke', 'HadAsthma', 'HadSkinCancer', 'HadCOPD', 'HadArthritis', 'HadDiabetes', 'HadKidneyDisease', 'HadObesity']]

chronic_diseases
# Out:
#            Sex HadHeartAttack HadAngina HadStroke HadAsthma HadSkinCancer  \
# 0       Female             No        No        No        No            No
# 1       Female             No        No        No        No           Yes
# 2       Female             No        No        No        No           Yes
# 3       Female             No        No        No       Yes            No
# 4       Female             No        No        No        No            No
# ...        ...            ...       ...       ...       ...           ...
# 430823  Female             No        No        No       Yes            No
# 430824  Female             No        No        No        No            No
# 430825  Female             No        No        No        No            No
# 430826    Male            Yes        No        No       Yes            No
# 430827    Male             No        No        No        No            No
#
#        HadCOPD HadArthritis HadDiabetes HadKidneyDisease HadObesity
# ...

# %% [markdown]
# - Displaying the count of individuals for each disease, indicating wether they have the disease or not.

# %%
# Printing all values count of each column starting from heart attack status.
for column in chronic_diseases.columns[1:]:
    print(chronic_diseases[column].value_counts(normalize=True), end='\n\n')
# Out:
# HadHeartAttack
# No     0.94313
# Yes    0.05687
# Name: proportion, dtype: float64
#
# HadAngina
# No     0.940028
# Yes    0.059972
# Name: proportion, dtype: float64
#
# HadStroke
# No     0.957106
# Yes    0.042894
# Name: proportion, dtype: float64
#
# HadAsthma
# No     0.848493
# Yes    0.151507
# Name: proportion, dtype: float64
#
# HadSkinCancer
# No     0.918691
# Yes    0.081309
# Name: proportion, dtype: float64
#
# HadCOPD
# No     0.920075
# Yes    0.079925
# Name: proportion, dtype: float64
#
# HadArthritis
# No     0.656375
# Yes    0.343625
# Name: proportion, dtype: float64
#
# HadDiabetes
# No                  0.829720
# Yes                 0.138127
# Borderline          0.023403
# During Pregnancy    0.008750
# Name: proportion, dtype: float64
#
# HadKidneyDisease
# No     0.954365
# Yes    0.045635
# Name: proportion, dtype: float64
#
# HadObesity
# No     0.698822
# Yes    0.301178
# Name: proportion, dtype: float64

# %% [markdown]
# - Now, let's see the correlation between each chronic condition with heart disease status.

# %%
set_size_style(18,15,'ticks')
for i,column in enumerate(chronic_diseases.columns[2:],1):
    plt.subplot(3,3,i)
    # print(i,column)
    
    ax = sns.countplot(data=chronic_diseases, x=column, hue='HadHeartAttack')
    customize_plot(ax, 'Correlation b/w Heart Attack and '+column[3:] , column, 'People count', 12,10)

    # Annotating bar labels
    for container in ax.containers:
        ax.bar_label(container)
plt.suptitle('Different diseases and chronic conditions coorealtion with heart attack', size=25, fontweight='bold')
plt.tight_layout(w_pad=1, h_pad=2)

# %% [markdown]
# - People often suffer Angina pain or stroke before a heart attack.

# %% [markdown]
# - Now we will find out, how does the presence of these chronic conditions correlate with heart disease prevalence.

# %%
# First we will melt the dataframe, so that all diseases comes in one column and their status in another column
melted_df = chronic_diseases.melt(id_vars=['Sex', 'HadHeartAttack'], value_vars=['HadAsthma', 'HadSkinCancer', 'HadCOPD', 'HadKidneyDisease', 'HadArthritis', 'HadDiabetes', 'HadObesity'], var_name='Disease', value_name='Status')
melted_df
# Out:
#             Sex HadHeartAttack     Disease Status
# 0        Female             No   HadAsthma     No
# 1        Female             No   HadAsthma     No
# 2        Female             No   HadAsthma     No
# 3        Female             No   HadAsthma    Yes
# 4        Female             No   HadAsthma     No
# ...         ...            ...         ...    ...
# 3015791  Female             No  HadObesity     No
# 3015792  Female             No  HadObesity     No
# 3015793  Female             No  HadObesity     No
# 3015794    Male            Yes  HadObesity    Yes
# 3015795    Male             No  HadObesity     No
#
# [3015796 rows x 4 columns]

# %%
# Selecting all individuals with presence of diseases
individuals_with_diseases = melted_df[melted_df['Status'] == 'Yes']
individuals_with_diseases
# Out:
#             Sex HadHeartAttack     Disease Status
# 3        Female             No   HadAsthma    Yes
# 12         Male             No   HadAsthma    Yes
# 17       Female             No   HadAsthma    Yes
# 32       Female            Yes   HadAsthma    Yes
# 43       Female             No   HadAsthma    Yes
# ...         ...            ...         ...    ...
# 3015781    Male             No  HadObesity    Yes
# 3015782    Male             No  HadObesity    Yes
# 3015783  Female             No  HadObesity    Yes
# 3015790    Male             No  HadObesity    Yes
# 3015794    Male            Yes  HadObesity    Yes
#
# [490166 rows x 4 columns]

# %%
# Plotting bar chart
set_size_style(12,6,'darkgrid')
ax= sns.countplot(data=individuals_with_diseases, x='Disease', hue='HadHeartAttack', palette=['tab:orange','tab:blue'])

customize_plot(ax, 'Heart Disease Disparity among Individuals with Chronic Conditions','Chronic condition' , 'People count', 10,10)

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# - Here you can see that many people reported heart disease who previously have problems of arthritis, diabetes and obesity.

# %% [markdown]
# - Pivoting the table, to calculate summary stats and normalizing the values.

# %%
pivoted_df = individuals_with_diseases.pivot_table(values='Status',index='Disease', columns='HadHeartAttack', aggfunc='count')
pivoted_df
# Out:
# HadHeartAttack        No    Yes
# Disease
# HadArthritis      133126  14137
# HadAsthma          60452   4608
# HadCOPD            28585   5705
# HadDiabetes        50971   8428
# HadKidneyDisease   16140   3449
# HadObesity        121073   8683
# HadSkinCancer      31420   3389

# %%
normalized_pivot = round(pivoted_df.div( pivoted_df.sum( axis=1 ) , axis=0 ), 2)
normalized_pivot
# Out:
# HadHeartAttack      No   Yes
# Disease
# HadArthritis      0.90  0.10
# HadAsthma         0.93  0.07
# HadCOPD           0.83  0.17
# HadDiabetes       0.86  0.14
# HadKidneyDisease  0.82  0.18
# HadObesity        0.93  0.07
# HadSkinCancer     0.90  0.10

# %%
# Plotting a stacked bar chart
set_size_style(10,8,'darkgrid')

ax = pivoted_df.plot.bar(stacked=True, color=['tab:orange','tab:blue'], figsize=(10,5))
ax.tick_params('x',rotation=0)
customize_plot(ax,'Correlation b/w Heart Disease and Chronic Conditions','Chronic conditions', 'People count',12,10)

for i,container in enumerate(ax.containers):
    if(i==0):
        ax.bar_label(container, size=10, color='white', labels=pivoted_df['No'], label_type='center')
    else:
        ax.bar_label(container, padding=-20, size=10, color='black', labels=pivoted_df['Yes'])
        ax.bar_label(container, padding=2, size=10, color='black', fmt='Total: %g')

plt.show()

# %%
# Plotting with normalized pivot 
ax = normalized_pivot.plot.bar(stacked=True, color=['tab:orange','tab:blue'], figsize=(10,5))
ax.tick_params('x',rotation=0)
customize_plot(ax,'Correlation b/w Heart Disease and Chronic Conditions(normalized)','Disease', 'People( % )',12,10)

for i,container in enumerate(ax.containers):
    if(i==0):
        ax.bar_label(container, size=10, color='white', labels=normalized_pivot['No'], label_type='center')
    else:
        ax.bar_label(container, padding=-15, size=10, color='black', labels=normalized_pivot['Yes'])

# %%
# Subsetting only "Yes" column from pivoted dataframe
has_heart_disease = pivoted_df['Yes']

# Plotting pie chart which shows share of chronic conditions
set_size_style(6,6)
ax = has_heart_disease.plot.pie(labels=has_heart_disease.index, autopct='%.1f%%' , explode=[0.1,0,0,0.05,0,0.05,0])
ax.set_title('Pravalence of Chronic Conditions Among Heart Patients', fontweight='bold')
ax.set_ylabel('')
# plt.legend()
plt.show()

# %% [markdown]
# ### **Findings:**
# - Approx. 6% of the sample data population are heart patients.
# - Almost 30% of the people are obese i.e their BMI is greater than 30.
# - Certain chronic conditions are not so strongly associated with cardiovascular health disparities.
# - Individuals previously having chronic diseases such as COPD(Chronic obstructive pulmonary disease), diabetes, kidney diseases are more likely to have heart diseases as 17%, 14% and 18% respectively of them are also heart patients.
# - Other conditions like arthritis(10%), asthma(7%), skin cancer(10%), obesity(7%), also have a chance of developing a heart disease.
# - Considering overall heart patients with chronic conditions previously, Nearly one third one them had arthiris before, around 17-18% are diabetic, other 18% are obese.

# %% [markdown]
# # Behavioral Correlations:

# %% [markdown]
# - Explore the relationships between health behaviors (physical activity, sleep, alcohol consumption) and the prevalence of heart disease.
# -Identify key behavioral factors that may contribute to cardiovascular health disparities

# %%
heart_data.columns
# Out:
# Index(['Sex', 'GeneralHealth', 'PhysicalHealthDays', 'MentalHealthDays',
#        'PhysicalActivities', 'SleepHours', 'HadHeartAttack', 'HadAngina',
#        'HadStroke', 'HadAsthma', 'HadSkinCancer', 'HadCOPD',
#        'HadDepressiveDisorder', 'HadKidneyDisease', 'HadArthritis',
#        'HadDiabetes', 'DeafOrHardOfHearing', 'BlindOrVisionDifficulty',
#        'DifficultyConcentrating', 'DifficultyWalking',
#        'DifficultyDressingBathing', 'DifficultyErrands', 'SmokerStatus',
#        'ECigaretteUsage', 'RaceEthnicityCategory', 'AgeCategory',
#        'HeightInMeters', 'WeightInKilograms', 'BMI', 'AlcoholDrinkers',
#        'CovidPos', 'HadObesity'],
#       dtype='object')

# %% [markdown]
# - The health behaviors may include Physical Activity, Sleep Hours, Smoker Status, ECigarette Usage, Alcohol Drinkers.

# %% [markdown]
# - First, we're examining how behaviors like smoking, e-cigarette use, and alcohol consumption relate to heart diseases.

# %%
behavioral_factors = ['SmokerStatus', 'ECigaretteUsage', 'AlcoholDrinkers', 'PhysicalActivities']
for factor in behavioral_factors:
    print(heart_data[factor].value_counts(normalize=True)*100, end = '\n\n')
# Out:
# SmokerStatus
# Never smoked                 59.956219
# Former smoker                27.888272
# Current smoker(Every day)     8.754128
# Current smoker(Some days)     3.401381
# Name: proportion, dtype: float64
#
# ECigaretteUsage
# Never         76.134839
# Not at all    18.441010
# Somedays       2.873641
# Everyday       2.550510
# Name: proportion, dtype: float64
#
# AlcoholDrinkers
# Yes    53.036364
# No     46.963636
# Name: proportion, dtype: float64
#
# PhysicalActivities
# Yes    76.020573
# No     23.979427
# Name: proportion, dtype: float64

# %% [markdown]
# - Now, let's explore the relation between each behaviorial factor with heart disease status.

# %%
set_size_style(15,18,'ticks')
for i,col in enumerate(behavioral_factors,1):
    plt.subplot(3,2,i)    
    ax = sns.countplot(data=heart_data, x=col, hue='HadHeartAttack')
    customize_plot(ax,f"Relationship Between Heart Attack & {col}" , col, 'Individuals', 12,10)
    for container in ax.containers:
        ax.bar_label(container)
plt.suptitle('Different diseases and Behavioral Factors correlation with heart attack', size=25, fontweight='bold')
plt.tight_layout(w_pad=2, h_pad = 2)

# %% [markdown]
# - Individuals who used to smoke in the past are often affected by heart attacks. Additionally, it's noteworthy that individuals who have never used e-cigarettes and do not consume alcohol also experience heart attacks, which is quite surprising.

# %% [markdown]
# - Now, we will investigate how the presence of these factors is connected to the prevalence of heart disease.

# %%
SmokerData = heart_data[(heart_data['SmokerStatus'] == 'Current smoker(Every day)') | (heart_data['SmokerStatus'] == 'Current smoker(Some days)')]
ECigaretteData = heart_data[(heart_data['ECigaretteUsage'] == 'Everyday') | (heart_data['ECigaretteUsage'] == 'Somedays')]
AlcoholDrinkersData = heart_data[(heart_data['AlcoholDrinkers'] == 'Yes')]
PhysicallyActiveData = heart_data[(heart_data['PhysicalActivities'] == 'Yes')]

set_size_style(10,4,'ticks')

plt.suptitle('Correlation of Smoking, E-Cigarette Use, Alcohol Consumption and Physical Activities with Heart Attack Risk', fontweight='bold')

plt.subplot(1, 4, 1)
ax1 = sns.countplot(data=SmokerData, x='HadHeartAttack')
for container in ax1.containers:
    ax1.bar_label(container)
customize_plot(ax1,"Smokers Data" ,'HadHeartAttack', 'Individuals', 12,10)

plt.subplot(1, 4, 2)
ax2 = sns.countplot(data=ECigaretteData, x='HadHeartAttack')
for container in ax2.containers:
    ax2.bar_label(container)
customize_plot(ax2,"E-Cigarette Users Data" ,'HadHeartAttack', 'Individuals', 12,10)

plt.subplot(1, 4, 3)
ax3 = sns.countplot(data=AlcoholDrinkersData, x='HadHeartAttack')
for container in ax3.containers:
    ax3.bar_label(container)
customize_plot(ax3,"Alcohol Drinkers Data" ,'HadHeartAttack', 'Individuals', 12,10)

plt.subplot(1, 4, 4)
ax4 = sns.countplot(data=PhysicallyActiveData, x='HadHeartAttack')
for container in ax4.containers:
    ax4.bar_label(container)
customize_plot(ax4,"Physically Active Data" ,'HadHeartAttack', 'Individuals', 12,10)
plt.tight_layout()

# %%
Smoker_heart_attack_percentage = (SmokerData['HadHeartAttack'].value_counts(normalize=True) * 100).to_dict()
ECigarette_heart_attack_percentage = (ECigaretteData['HadHeartAttack'].value_counts(normalize=True) * 100).to_dict()
Alcohol_heart_attack_percentage = (AlcoholDrinkersData['HadHeartAttack'].value_counts(normalize=True) * 100).to_dict()
PhysicalActivities_heart_attack_percentage = (PhysicallyActiveData['HadHeartAttack'].value_counts(normalize=True) * 100).to_dict()


behavior_percentages = {
    'Smoking': Smoker_heart_attack_percentage.get('Yes'),
    'E-Cigarette Use': ECigarette_heart_attack_percentage.get('Yes'),
    'Alcohol Consumption': Alcohol_heart_attack_percentage.get('Yes'),
    'Physically Active': PhysicalActivities_heart_attack_percentage.get('Yes')
}
plt.pie(behavior_percentages.values(), labels=behavior_percentages.keys(), autopct='%1.1f%%', startangle=90,explode=[0,0.05,0.05,0.05])
plt.title('Prevalence of Health Behaviors among Heart Patients', weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Prevalence of Health Behaviors among Heart Patients')

# %% [markdown]
# - People who smoke are at a higher risk of developing heart disease or experiencing a heart attack.

# %% [markdown]
# - Next, we'll investigate other behavioral factors such as Sleep Hours.

# %%
heart_data.groupby('HadHeartAttack').agg({'SleepHours':'mean'})
# Out:
#                 SleepHours
# HadHeartAttack
# No                7.022916
# Yes               7.032850

# %%
ax = sns.boxplot(x='HadHeartAttack', y='SleepHours', data=heart_data)
customize_plot(ax,"Relationship Between Heart Attack & Sleep Hours" ,'HadHeartAttack' , 'Sleep Hours', 12,10)

# %% [markdown]
# - The box plot illustrates that the distribution of sleep hours is similar between individuals who have experienced a heart attack and those who have not. So, now we will explore the sleep hours among those who have heart diseases.

# %%
heart_attack_sleep_hours = heart_data[heart_data['HadHeartAttack'] == 'Yes']['SleepHours']
heart_attack_sleep_hours.describe()
# Out:
# count    23988.000000
# mean         7.032850
# std          1.647642
# min          3.000000
# 25%          6.000000
# 50%          7.000000
# 75%          8.000000
# max         13.000000
# Name: SleepHours, dtype: float64

# %%
set_size_style(10,4,'ticks')
ax =sns.histplot(heart_attack_sleep_hours, bins=10, kde=True)
customize_plot(ax,"Distribution of Sleep Hours among Individuals with Heart Diseases" ,'Sleep Hours' , 'Frequency', 12,10)
plt.show()

# %% [markdown]
# - The above distribution is slightly right skewed which suggests that most people with heart diseases tend to sleep for about 6 to 8 hours.

# %% [markdown]
# # **Effect of Mental Health on Heart Disease:**

# %%
mental_health_cols = heart_data[['GeneralHealth', 'HadHeartAttack', 'HadDepressiveDisorder', 'MentalHealthDays']]
mental_health_cols
# Out:
#        GeneralHealth HadHeartAttack HadDepressiveDisorder  MentalHealthDays
# 0          Very good             No                    No               0.0
# 1          Excellent             No                    No               0.0
# 2          Very good             No                    No               3.0
# 3          Excellent             No                    No               0.0
# 4               Fair             No                    No               0.0
# ...              ...            ...                   ...               ...
# 430823          Good             No                   Yes               3.0
# 430824     Excellent             No                    No               2.0
# 430825          Poor             No                    No              30.0
# 430826     Very good            Yes                    No               0.0
# 430827     Very good             No                    No               1.0
#
# [430828 rows x 4 columns]

# %%
set_size_style(8,6,'darkgrid')
ax = sns.countplot(data=mental_health_cols, x='HadHeartAttack', hue='HadDepressiveDisorder', palette='Set2')
customize_plot(ax,'Correlation of Depression and Heart Disease', 'HadHeartAttack', 'People count', 12, 10)

for container in ax.containers:
    ax.bar_label(container, fmt='%g persons')

# %% [markdown]
# - This chart shows that most of the people neither have heart disease nor depressive disorder.
# - Among people having heart problems, a significant big portion of 6000+ have depressive disorders also.

# %%
cross_pivot = pd.crosstab(index=mental_health_cols['HadHeartAttack'], columns=mental_health_cols['HadDepressiveDisorder'], normalize=True)
print(cross_pivot)

set_size_style(8,6)
ax = sns.heatmap(data=cross_pivot,cmap='flare', linewidths=1, annot=True)
customize_plot(ax, 'Heatmap: Normalized Correlation between Depression and Heart Disease', 'Had Depression', 'Had Heart Attack', 12,10)
# Out:
# HadDepressiveDisorder        No       Yes
# HadHeartAttack
# No                     0.749425  0.193797
# Yes                    0.042530  0.014248

# %% [markdown]
# - Mostly 75% people donot have depressive disorder and also have a good heart health.
# - 19% people are suffering from depression but also don't have a heart disease.
# - Around 4% people don't have depressive disorder but facing heart disease.
# - Very few people i.e around 1.5% have faced depressive disorder before developing heart problems.

# %%
depress_heart_patient = mental_health_cols[mental_health_cols['HadHeartAttack'] == 'Yes'].value_counts('HadDepressiveDisorder', normalize=True)

# Plotting pie chart which shows share of heart patients with and without depressive disorder
set_size_style(6,6)
ax = depress_heart_patient.plot.pie(labels=depress_heart_patient.index, autopct='%.2f%%', explode=[0,0.1], startangle=45, shadow=True, textprops = {'color' : 'white', 'fontweight' : 'bold', 'size': 14})
ax.set_title('Pravalence of Depressive Disorder Among Heart Patients', fontweight='bold')
ax.set_ylabel(None)
plt.legend()
plt.show()

# %% [markdown]
# - If we consider all the heart patients, then one out of four people are facing depressive disorders.

# %% [markdown]
# Now, include mental health days in our analysis, it is defined as how many days during the past 30 days was your mental health not good?

# %%
set_size_style(12,6,'darkgrid')
ax = sns.histplot( data=mental_health_cols, x='MentalHealthDays', bins=30, kde=True)
ax.set_xticks([x for x in range(0,31)])
customize_plot(ax, 'Distribution of Mental Health Days', 'Day', 'Count',12,10)

plt.show()

# %% [markdown]
# - The data seems to be highly skewed to the right.
# - Most of the people i.e more than 250,000, didn't face any issue related to mental health in past 30 days.
# - There are also people who are still facing mental health problems from the past 30 days.

# %%
# Let's see summary stats of mental health days column
mental_health_cols['MentalHealthDays'].describe()
# Out:
# count    422242.000000
# mean          4.385056
# std           8.355573
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           5.000000
# max          30.000000
# Name: MentalHealthDays, dtype: float64

# %%
pivot_table_mental_health = mental_health_cols.pivot_table(index='HadHeartAttack', columns='HadDepressiveDisorder', values='MentalHealthDays', aggfunc='median')

# %% [markdown]
# - Here values are aggregated by taking median of the values.
# - For right highly skewed data, where most of the values are clustered towards the left with a long tail extending to the right, the best measure of central tendency is typically the median.
# - The median is less affected by extreme values or outliers compared to the mean, making it a more robust measure for skewed distributions. It represents the middle value when the data is arranged in ascending or descending order. Since it is not influenced by extreme values, it provides a better representation of the typical value in the dataset for skewed distributions.

# %%
set_size_style(8,6)
ax = sns.heatmap(data=pivot_table_mental_health,cmap='crest', linewidths=1, annot=True)

customize_plot(ax, 'Interplay between Mental Health Days,Depression and Heart Attack', 'Depressive disorder', 'Heart disease', 12,10)

# %% [markdown]
# - People with depressive disorders and heart problems are more likely to face bad mental healt days, in the heatmap we can see the median days for such people is 10.
# - People have mostly report more than a week for bad mental health, who have depressive disorder.

# %% [markdown]
# # **Sensory Impairments and Cardiovascular Health:**

# %%
heart_data.columns
# Out:
# Index(['Sex', 'GeneralHealth', 'PhysicalHealthDays', 'MentalHealthDays',
#        'PhysicalActivities', 'SleepHours', 'HadHeartAttack', 'HadAngina',
#        'HadStroke', 'HadAsthma', 'HadSkinCancer', 'HadCOPD',
#        'HadDepressiveDisorder', 'HadKidneyDisease', 'HadArthritis',
#        'HadDiabetes', 'DeafOrHardOfHearing', 'BlindOrVisionDifficulty',
#        'DifficultyConcentrating', 'DifficultyWalking',
#        'DifficultyDressingBathing', 'DifficultyErrands', 'SmokerStatus',
#        'ECigaretteUsage', 'RaceEthnicityCategory', 'AgeCategory',
#        'HeightInMeters', 'WeightInKilograms', 'BMI', 'AlcoholDrinkers',
#        'CovidPos', 'HadObesity'],
#       dtype='object')

# %%
# Subsetting all necessary columns
sensory_imp_subset = heart_data[['HadHeartAttack', 'SmokerStatus', 'ECigaretteUsage', 'HadObesity', 'PhysicalActivities', 'AlcoholDrinkers', 'DeafOrHardOfHearing' , 'BlindOrVisionDifficulty', 'DifficultyConcentrating']]
sensory_imp_subset
# Out:
#        HadHeartAttack               SmokerStatus ECigaretteUsage HadObesity  \
# 0                  No               Never smoked      Not at all         No
# 1                  No               Never smoked           Never         No
# 2                  No               Never smoked           Never         No
# 3                  No  Current smoker(Some days)           Never         No
# 4                  No               Never smoked           Never         No
# ...               ...                        ...             ...        ...
# 430823             No               Never smoked           Never         No
# 430824             No               Never smoked           Never         No
# 430825             No  Current smoker(Every day)        Somedays         No
# 430826            Yes               Never smoked           Never        Yes
# 430827             No              Former smoker      Not at all         No
#
# ...

# %%
for column in sensory_imp_subset.columns[1:]:
    print(sensory_imp_subset[column].value_counts(), end="\n\n")
# Out:
# SmokerStatus
# Never smoked                 239657
# Former smoker                111475
# Current smoker(Every day)     34992
# Current smoker(Some days)     13596
# Name: count, dtype: int64
#
# ECigaretteUsage
# Never         304180
# Not at all     73677
# Somedays       11481
# Everyday       10190
# Name: count, dtype: int64
#
# HadObesity
# No     301072
# Yes    129756
# Name: count, dtype: int64
#
# PhysicalActivities
# Yes    326798
# No     103083
# Name: count, dtype: int64
#
# AlcoholDrinkers
# Yes    206286
# No     182666
# Name: count, dtype: int64
#
# DeafOrHardOfHearing
# No     376490
# Yes     37605
# Name: count, dtype: int64
#
# BlindOrVisionDifficulty
# No     390653
# Yes     22548
# Name: count, dtype: int64
#
# DifficultyConcentrating
# No     362491
# Yes     48159
# Name: count, dtype: int64

# %%
set_size_style(16,4,'darkgrid')
for i,column in enumerate(sensory_imp_subset.columns[-3:],1):
    # print(column)
    plt.subplot(1,3,i)
    ax = sns.countplot(data=sensory_imp_subset, x='HadHeartAttack', hue=column)
    for container in ax.containers:
        ax.bar_label(container)

# %% [markdown]
# - The above chart represents count of sensory impaired individuals having heart disease or not.

# %%
melted_df = sensory_imp_subset.melt(id_vars=['HadHeartAttack'], value_vars=['DeafOrHardOfHearing',
       'BlindOrVisionDifficulty', 'DifficultyConcentrating'], var_name='SensoryImpairments', value_name='Status')
melted_df
# Out:
#         HadHeartAttack       SensoryImpairments Status
# 0                   No      DeafOrHardOfHearing     No
# 1                   No      DeafOrHardOfHearing     No
# 2                   No      DeafOrHardOfHearing     No
# 3                   No      DeafOrHardOfHearing     No
# 4                   No      DeafOrHardOfHearing     No
# ...                ...                      ...    ...
# 1292479             No  DifficultyConcentrating     No
# 1292480             No  DifficultyConcentrating     No
# 1292481             No  DifficultyConcentrating    NaN
# 1292482            Yes  DifficultyConcentrating     No
# 1292483             No  DifficultyConcentrating    Yes
#
# [1292484 rows x 3 columns]

# %%
# Selecting all rows with presence of sensory impairments
melted_df = melted_df[melted_df['Status'] == 'Yes']
melted_df
# Out:
#         HadHeartAttack       SensoryImpairments Status
# 14                  No      DeafOrHardOfHearing    Yes
# 21                  No      DeafOrHardOfHearing    Yes
# 27                  No      DeafOrHardOfHearing    Yes
# 29                  No      DeafOrHardOfHearing    Yes
# 30                  No      DeafOrHardOfHearing    Yes
# ...                ...                      ...    ...
# 1292414             No  DifficultyConcentrating    Yes
# 1292416            Yes  DifficultyConcentrating    Yes
# 1292451             No  DifficultyConcentrating    Yes
# 1292465             No  DifficultyConcentrating    Yes
# 1292483             No  DifficultyConcentrating    Yes
#
# [108312 rows x 3 columns]

# %%
sensory_heart_pivot = melted_df.pivot_table(index='SensoryImpairments', columns='HadHeartAttack', values='Status', aggfunc='count')
sensory_heart_pivot
# Out:
# HadHeartAttack              No   Yes
# SensoryImpairments
# BlindOrVisionDifficulty  19592  2956
# DeafOrHardOfHearing      32654  4951
# DifficultyConcentrating  43840  4319

# %%
normalized_pivot = round(sensory_heart_pivot.div(sensory_heart_pivot.sum(axis=1), axis=0),2)
normalized_pivot
# Out:
# HadHeartAttack             No   Yes
# SensoryImpairments
# BlindOrVisionDifficulty  0.87  0.13
# DeafOrHardOfHearing      0.87  0.13
# DifficultyConcentrating  0.91  0.09

# %%
# Plotting with normalized pivot 
ax = normalized_pivot.plot.bar(stacked=True, color=['tab:orange','tab:blue'], figsize=(10,5))
ax.tick_params('x',rotation=0)
customize_plot(ax,'Correlation b/w Heart Disease and Sensory Impairments','Sensory Impairment', 'People( % )',12,10)

for i,container in enumerate(ax.containers):
    if(i==0):
        ax.bar_label(container, size=10, color='white', labels=normalized_pivot['No'], label_type='center')
    else:
        ax.bar_label(container, padding=-15, size=10, color='black', labels=normalized_pivot['Yes'])

# %% [markdown]
# - 13% of blind and deaf people are heart patients.
# - 9% people having are difficulty in concentration facing heart disease.
# - Sensory impairment doesn't have any siginifact impact on heart disease pravalence.

# %%
sensory_imp_subset.columns
# Out:
# Index(['HadHeartAttack', 'SmokerStatus', 'ECigaretteUsage', 'HadObesity',
#        'PhysicalActivities', 'AlcoholDrinkers', 'DeafOrHardOfHearing',
#        'BlindOrVisionDifficulty', 'DifficultyConcentrating'],
#       dtype='object')

# %%
# Names of all risk factor of columns
risk_factors = ['SmokerStatus', 'ECigaretteUsage', 'HadObesity', 'PhysicalActivities', 'AlcoholDrinkers']

# %%
# Loop for generating heatmap chart for all the risk factor columns

def senory_imp_cross_table_heat_map(df, column):
    # First melting the sensory impairment columns
    melted_df = df.melt(id_vars=[column], value_vars=['DeafOrHardOfHearing', 'BlindOrVisionDifficulty', 'DifficultyConcentrating'], var_name='SensoryImpairments', value_name='Status')
    
    # Select the rows with true status so that we can count only individuals with sensory impairments.
    melted_df = melted_df[melted_df['Status'] == 'Yes']
    
    # pivoting the melted df using cross tab function so that all the categories of sensory impairments becomes index and risk factors in columns 
    pivoted_df = round(pd.crosstab(index=melted_df['SensoryImpairments'], columns=melted_df[column], normalize=True),2)
    
    ax =sns.heatmap(data=pivoted_df, cmap='flare', linewidths=1, annot=True)

    customize_plot(ax, f'Heatmap: Normalized Correlation between Sensory Impairments and {column}',column, 'Sensory Impairment', 12,10)
    plt.show()

# %%
senory_imp_cross_table_heat_map(sensory_imp_subset, 'SmokerStatus')

# %% [markdown]
# - You can see in the chart that there are very less people with difficulty concentrating among smokers in comparison with non-smokers.
# - It is due to the fact that smoking can improve concentration and attention. This is because a smoker's body needs a constant level of nicotine, and when these levels dip, it can cause withdrawal symptoms. As a result, the increased concentration after a cigarette is the body's way of thanking the smoker for satisfying its addiction.
# - People with blindness and deafness, commonly donot smoke as there are very less people, around 1%-4%.

# %%
senory_imp_cross_table_heat_map(sensory_imp_subset, 'ECigaretteUsage')

# %% [markdown]
# - Same readings for E-Ciggatette and Vape users.

# %%
pivoted_df = round(pd.crosstab(index=sensory_imp_subset['DifficultyConcentrating'], columns=sensory_imp_subset['PhysicalActivities'], normalize=True),2)
    
ax =sns.heatmap(data=pivoted_df, cmap='flare', linewidths=1, annot=True)

customize_plot(ax, f'Correlation between DifficultyConcentration and PhysicalActivity','PhysicalActivities', 'DifficultyConcentrating', 12,10)
plt.show()

# %% [markdown]
# - 70% people are physically active and donot have any difficulty in concentration.
# - When you do any type of intense physical activity, it causes blood to flow to the brain. This in turn fires up your neurones and promotes cell growth, particularly in the hippocampus. This means that physical exercise can improve your concentration and help you focus.

# %% [markdown]
# ## Impact of COVID-19

# %%
covid_count = heart_data['CovidPos'].value_counts()
covid_count
# Out:
# CovidPos
# No     262802
# Yes    122031
# Name: count, dtype: int64

# %%
plt.pie(covid_count, labels = covid_count.index, autopct='%.2f%%', explode=[0,0.01], startangle=45, shadow=True)
plt.title('COVID-19 cases among people', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'COVID-19 cases among people')

# %% [markdown]
# - The majority of individuals in the dataset have not tested positive for COVID-19, with only about 30% of individuals being identified as COVID-19 positive.

# %%
set_size_style(5,5,'darkgrid')
ax = sns.countplot(data = heart_data, x = 'CovidPos', hue = 'HadHeartAttack', palette='viridis')
customize_plot(ax,"Relation Between Heart Attacks and COVID-19","COVID-19","Individuals",12,10)
for c in ax.containers:
    ax.bar_label(c)

# %%
cross_pivot = pd.crosstab(index=heart_data['CovidPos'], columns=heart_data['HadHeartAttack'], normalize=True)
cross_pivot*100
# Out:
# HadHeartAttack         No       Yes
# CovidPos
# No              64.121320  4.168561
# Yes             30.193357  1.516762

# %%
set_size_style(8,6)
ax = sns.heatmap(data=cross_pivot,cmap='flare', linewidths=1, annot=True)
customize_plot(ax, 'Heatmap: Normalized Correlation between COVID-19 and Heart Disease', 'Had Heart Attack', 'COVID-19', 12,10)

# %% [markdown]
# - The majority, around 64%, of people do not have COVID-19 and maintain good heart health.
# - About 30% of those who tested positive for COVID-19 do not have heart disease.
# - Approximately 4% of individuals do not have COVID-19 but still experience heart disease.
# - A small percentage, around 1.5%, had COVID-19 before developing heart problems

# %% [markdown]
# - Now we explore the relation between different Risk Factors and COVID-19

# %%
set_size_style(15, 12, 'darkgrid')

for i, risk_factor in enumerate(risk_factors, 1):
    plt.subplot(3, 2, i) 
    ax = sns.countplot(data=heart_data, x=risk_factor, hue='CovidPos', palette='viridis')
    customize_plot(ax, f"Relation b/w {risk_factor} & COVID-19", risk_factor, "Individuals", 15, 12)
    
    for c in ax.containers:
        ax.bar_label(c)
plt.tight_layout()

# %%
set_size_style(13, 25, 'darkgrid')

for i, risk_factor in enumerate(risk_factors, 1):
    plt.subplot(5, 1, i) 
    cross_pivot = pd.crosstab(index=heart_data['CovidPos'], columns=heart_data[risk_factor], normalize=True)
    print(cross_pivot*100)
    ax = sns.heatmap(data=cross_pivot,cmap='flare', linewidths=1, annot=True)
    customize_plot(ax, f'Heatmap: Normalized Correlation between COVID-19 and {risk_factor}', risk_factor, 'COVID-19', 12,10)
plt.tight_layout()
# Out:
# SmokerStatus  Current smoker(Every day)  Current smoker(Some days)  \
# CovidPos
# No                             6.509853                   2.352467
# Yes                            2.137583                   0.964752
#
# SmokerStatus  Former smoker  Never smoked
# CovidPos
# No                19.137219     40.269900
# Yes                8.704494     19.923731
# ECigaretteUsage  Everyday      Never  Not at all  Somedays
# CovidPos
# No               1.452175  52.882438   12.197800  1.741201
# Yes              1.066372  23.495915    6.078945  1.085153
# HadObesity         No        Yes
# CovidPos
# No          47.840492  20.449390
# Yes         20.580615  11.129503
# PhysicalActivities         No        Yes
# CovidPos
# No                  16.672395  51.611467
# Yes                  7.055929  24.660209
# AlcoholDrinkers         No        Yes
# CovidPos
# No               33.430611  34.813203
# Yes              13.699603  18.056583

# %% [markdown]
# - About 40% of individuals who never smoked tested negative for COVID-19. Only 3% of regular smokers tested positive for COVID-19. Additionally, 19% of former smokers tested negative for COVID-19.
# - Approximately 53% of individuals who never used e-cigarettes tested negative for COVID-19. Only 2% of regular e-cigarette users tested positive for COVID-19.
# - Around 50% of non-obese individuals tested negative for COVID-19, while 10% of obese individuals tested positive for COVID-19.
# - About 52% of physically active individuals tested negative for COVID-19, whereas only 7% of inactive individuals tested positive for COVID-19.
# - COVID-19 appears to be more common among alcohol drinkers.

# %%
other_risk_factor_covid = heart_data.groupby('CovidPos').agg({'PhysicalHealthDays':'mean', 'MentalHealthDays':'mean', 'SleepHours':'mean'})
other_risk_factor_covid
# Out:
#           PhysicalHealthDays  MentalHealthDays  SleepHours
# CovidPos
# No                  4.206779          4.129938    7.070042
# Yes                 4.572776          4.922701    6.930112

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, risk_factor in enumerate(other_risk_factor_covid.columns, 1):
    plt.subplot(1, 3, i)
    plt.title(f"Relation b/w {risk_factor} and COVID-19", fontsize = 12, weight='bold')
    plt.pie(other_risk_factor_covid[risk_factor], labels=other_risk_factor_covid.index, autopct='%1.1f%%', startangle=90)
plt.legend(title = 'COVID-19')
plt.tight_layout()

# %% [markdown]
#  - Individuals who contracted COVID-19 tend to report a higher percentage of days with poor physical health and poor mental health compared to those who did not have COVID-19. This indicates that, on average, individuals affected by COVID-19 experience more days of poor physical and mental health within the past 30 days. However, the average number of sleep hours remains relatively similar between both groups.

# %% [markdown]
# - Now, we will examine the prevalence of heart disease among individuals who tested positive for COVID-19

# %%
covidpos_data= heart_data[heart_data['CovidPos']=='Yes']
covidpos_data
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 2       Female     Very good                 2.0               3.0
# 17      Female          Fair                 0.0              15.0
# 26      Female          Fair                23.0               3.0
# 30      Female          Good                 2.0               3.0
# 32      Female          Poor                14.0              14.0
# ...        ...           ...                 ...               ...
# 430819  Female          Fair                 0.0               7.0
# 430820    Male          Good                 0.0              15.0
# 430822    Male          Good                 0.0               0.0
# 430823  Female          Good                 0.0               3.0
# 430826    Male     Very good                 0.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 2                     Yes         5.0             No        No        No
# ...

# %%
heartdisease_among_covidpos = covidpos_data['HadHeartAttack'].value_counts()
heartdisease_among_covidpos
# Out:
# HadHeartAttack
# No     116194
# Yes      5837
# Name: count, dtype: int64

# %%
plt.pie(heartdisease_among_covidpos, labels=heartdisease_among_covidpos.index, autopct='%.2f%%', explode=[0, 0.01], startangle=45, shadow=True)
plt.title('Prevalence of Heart Disease Among Individuals who Tested Positive for COVID-19', fontweight='bold')
plt.legend(title='Had Heart Attack')
plt.show()

# %% [markdown]
# - About 95% of individuals who tested positive for COVID-19 had no experience of heart diseases.

# %% [markdown]
# # **Some Hypothesis questions:**
# ### Can you indicate which variables have a significant effect on the likelihood of heart disease?

# %%
all_heart_patients = heart_data[heart_data['HadHeartAttack'] == 'Yes']
all_heart_patients
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 5         Male          Poor                 1.0               0.0
# 26      Female          Fair                23.0               3.0
# 31        Male          Fair                30.0               0.0
# 32      Female          Poor                14.0              14.0
# 34      Female          Fair                 NaN               0.0
# ...        ...           ...                 ...               ...
# 430778    Male          Fair                 1.0               0.0
# 430802  Female          Good                10.0               0.0
# 430806    Male          Fair                 7.0              30.0
# 430812    Male          Good                 0.0               0.0
# 430826    Male     Very good                 0.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 5                      No         7.0            Yes        No       Yes
# ...

# %%
all_heart_patients = all_heart_patients.drop(columns=['HadHeartAttack'])
all_heart_patients.head(2)
# Out:
#        Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 5     Male          Poor                 1.0               0.0
# 26  Female          Fair                23.0               3.0
#
#    PhysicalActivities  SleepHours HadAngina HadStroke HadAsthma HadSkinCancer  \
# 5                  No         7.0        No       Yes        No            No
# 26                Yes         8.0       Yes        No        No            No
#
#     ...               SmokerStatus ECigaretteUsage RaceEthnicityCategory  \
# 5   ...               Never smoked           Never                 White
# 26  ...  Current smoker(Some days)           Never                 Black
#
#    AgeCategory HeightInMeters WeightInKilograms    BMI AlcoholDrinkers  \
# 5          80+           1.80             84.82  26.08              No
# 26       65-69           1.68            105.23  37.45             Yes
#
#    CovidPos HadObesity
# 5        No         No
# 26      Yes        Yes
#
# [2 rows x 31 columns]

# %%
all_heart_patients.columns
# Out:
# Index(['Sex', 'GeneralHealth', 'PhysicalHealthDays', 'MentalHealthDays',
#        'PhysicalActivities', 'SleepHours', 'HadAngina', 'HadStroke',
#        'HadAsthma', 'HadSkinCancer', 'HadCOPD', 'HadDepressiveDisorder',
#        'HadKidneyDisease', 'HadArthritis', 'HadDiabetes',
#        'DeafOrHardOfHearing', 'BlindOrVisionDifficulty',
#        'DifficultyConcentrating', 'DifficultyWalking',
#        'DifficultyDressingBathing', 'DifficultyErrands', 'SmokerStatus',
#        'ECigaretteUsage', 'RaceEthnicityCategory', 'AgeCategory',
#        'HeightInMeters', 'WeightInKilograms', 'BMI', 'AlcoholDrinkers',
#        'CovidPos', 'HadObesity'],
#       dtype='object')

# %%
for column in all_heart_patients.columns[4:]:
    print(all_heart_patients[column].value_counts(), end='\n\n')
# Out:
# PhysicalActivities
# Yes    15006
# No      9411
# Name: count, dtype: int64
#
# SleepHours
# 8.0     6911
# 7.0     5236
# 6.0     5064
# 5.0     2066
# 9.0     1454
# 4.0     1275
# 10.0    1108
# 3.0      404
# 12.0     362
# 11.0      88
# 13.0      20
# Name: count, dtype: int64
#
# HadAngina
# No     11695
# Yes    11615
# Name: count, dtype: int64
#
# HadStroke
# No     19552
# Yes     4754
# Name: count, dtype: int64
#
# HadAsthma
# No     19790
# Yes     4608
# Name: count, dtype: int64
#
# HadSkinCancer
# No     20822
# Yes     3389
# Name: count, dtype: int64
#
# HadCOPD
# No     18583
# Yes     5705
# Name: count, dtype: int64
#
# HadDepressiveDisorder
# No     18223
# Yes     6105
# Name: count, dtype: int64
#
# HadKidneyDisease
# No     20846
# Yes     3449
# Name: count, dtype: int64
#
# HadArthritis
# Yes    14137
# No     10219
# Name: count, dtype: int64
#
# HadDiabetes
# No                  15132
# Yes                  8428
# Borderline            764
# ...

# %% [markdown]
# After analyzing the dataset, we came to know that the variables which have significant effect on the likelihood of heart disease are:
# - Having Obesity.
# - Having Angina pain.
# - Having Depressive Disorder
# - Smoking
# - Having Arthritis.
# - Having Diabetes.
# - Lack of physical activity.

# %% [markdown]
# ### How many people have at least 1 of 3 major risk factors for heart disease: no physical activity, high cholesterol, and smoking?

# %%
three_risk_factors = heart_data[(heart_data['HadObesity']=='Yes') | heart_data['SmokerStatus'].isin(['Current smoker(Every day)', 'Current smoker(Some days)']) | (heart_data['PhysicalActivities'] == 'No') ]
three_risk_factors
# Out:
#            Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0       Female     Very good                 0.0               0.0
# 1       Female     Excellent                 0.0               0.0
# 3       Female     Excellent                 0.0               0.0
# 5         Male          Poor                 1.0               0.0
# 7       Female          Good                 0.0               0.0
# ...        ...           ...                 ...               ...
# 430816    Male     Very good                 0.0               0.0
# 430818    Male          Fair                30.0               1.0
# 430822    Male          Good                 0.0               0.0
# 430825  Female          Poor                30.0              30.0
# 430826    Male     Very good                 0.0               0.0
#
#        PhysicalActivities  SleepHours HadHeartAttack HadAngina HadStroke  \
# 0                      No         8.0             No        No        No
# ...

# %%
heart_data.shape
# Out:
# (430828, 32)

# %%
print(round(three_risk_factors.shape[0]/heart_data.shape[0] * 100,2))
# Out:
# 49.92

# %% [markdown]
# - Almost 50% of the population have atleast 1 major risk factor for heart disease.
