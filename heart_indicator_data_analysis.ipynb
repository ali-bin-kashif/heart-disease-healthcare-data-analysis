# %% [markdown]
# # <b> EDA on 2022 annual CDC survey data of 400k+ adults related to their health status.

# %% [markdown]
# ### **Contributers:**
#
# - Ali Bin Kashif : [Know about Ali here.](https://www.linkedin.com/in/ali-bin-kashif/)
# - Muhammad Aman : [Know about Aman here.](https://www.linkedin.com/in/muhammad-aman-5a9317288/)

# %% [markdown]
# ### <b>About Dataset:</b>
#
# According to the CDC, heart disease is a leading cause of death for people of most races in the U.S. (African Americans, American Indians and Alaska Natives, and whites). About half of all Americans (47%) have at least 1 of 3 major risk factors for heart disease: high blood pressure, high cholesterol, and smoking. Other key indicators include diabetes status, obesity (high BMI), not getting enough physical activity, or drinking too much alcohol. Identifying and preventing the factors that have the greatest impact on heart disease is very important in healthcare. In turn, developments in computing allow the application of machine learning methods to detect "patterns" in the data that can predict a patient's condition.
#
# The dataset originally comes from the CDC and is a major part of the Behavioral Risk Factor Surveillance System (BRFSS), which conducts annual telephone surveys to collect data on the health status of U.S. residents. As described by the CDC: "Established in 1984 with 15 states, BRFSS now collects data in all 50 states, the District of Columbia, and three U.S. territories. BRFSS completes more than 400,000 adult interviews each year, making it the largest continuously conducted health survey system in the world.

# %% [markdown]
# ### **Variables**:
#
# There are 40 variables(columns) in this dataset.
#
# - **State :** The U.S. state where the individual resides.
#
# - **Sex :** Gender of the individual (Male or Female).
#
# - **GeneralHealth :** Self-reported general health status of the individual.
#
# - **PhysicalHealthDays :** Number of days in the past 30 days that physical health was not good.
#
# - **MentalHealthDays :** Number of days in the past 30 days that mental health was not good.
#
# - **LastCheckupTime :** Time since the last routine checkup or health examination.
#
# - **PhysicalActivities :** Frequency of engaging in physical activities or exercises.
#
# - **SleepHours :** Average number of hours of sleep per night.
#
# - **RemovedTeeth :** Number of permanent teeth removed due to dental issues.
#
# - **HadHeartAttack :** Whether the individual has had a heart attack.
#
# - **HadAngina :** Whether the individual has experienced angina (chest pain or discomfort).
#
# - **HadStroke :** Whether the individual has had a stroke.
#
# - **HadAsthma :** Whether the individual has had asthma.
#
# - **HadSkinCancer :** Whether the individual has had skin cancer.
#
# - **HadCOPD :** Whether the individual has had Chronic Obstructive Pulmonary Disease (COPD).
#
# - **HadDepressiveDisorder :** Whether the individual has had a depressive disorder.
#
# - **HadKidneyDisease :** Whether the individual has had kidney disease.
#
# - **HadArthritis :** Whether the individual has had arthritis.
#
# - **HadDiabetes :** Whether the individual has had diabetes.
#
# - **DeafOrHardOfHearing :** Whether the individual is deaf or hard of hearing.
#
# - **BlindOrVisionDifficulty :** Whether the individual has blindness or vision difficulty.
#
# - **DifficultyConcentrating :** Self-reported difficulty in concentrating.
#
# - **DifficultyWalking :** Self-reported difficulty in walking.
#
# - **DifficultyDressingBathing :** Self-reported difficulty in dressing or bathing.
#
# - **DifficultyErrands :** Self-reported difficulty in running errands.
#
# - **SmokerStatus :** Current smoking status of the individual (smoker, former smoker, non-smoker).
#
# - **ECigaretteUsage :** Whether the individual uses e-cigarettes.
#
# - **ChestScan :** Whether the individual has had a chest scan.
#
# - **RaceEthnicityCategory :** Categorized race or ethnicity of the individual.
#
# - **AgeCategory :** Categorized age group of the individual.
#
# - **HeightInMeters :** Height of the individual in meters.
#
# - **WeightInKilograms :** Weight of the individual in kilograms.
#
# - **BMI :** Body Mass Index calculated from height and weight.
#
# - **AlcoholDrinkers :** Whether the individual consumes alcohol.
#
# - **HIVTesting :** Whether the individual has undergone HIV testing.
#
# - **FluVaxLast12 :** Whether the individual received a flu vaccine in the last 12 months.
#
# - **PneumoVaxEver :** Whether the individual has ever received a pneumonia vaccine.
#
# - **TetanusLast10Tdap :** Time since the last tetanus vaccination (in the last 10 years, received Tdap).
#
# - **HighRiskLastYear :** Whether the individual has been considered at high risk for the past year.
#
# - **CovidPos :** Whether the individual tested positive for COVID-19.

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# ### **Understanding and Mitigating Cardiovascular Health Disparities:** An In-Depth Analysis of Risk Factors and Health Behaviors in the Adult Population.
#
# The problem centers on identifying and understanding the factors that exert the most significant influence on heart disease prevalence.This exploration is crucial for healthcare initiatives and interventions aimed at prevention and management. The dataset encompasses a range of variables, including demographic information, health behaviors, chronic conditions, and COVID-19 status, providing a rich source for uncovering patterns, correlations, and disparities in cardiovascular health.
#
# We're looking at big questions like what things make heart problems more likely, how mental and physical health are linked, what habits and steps help prevent heart issues, how other health problems affect the heart, and if issues like hearing or vision problems are connected to heart disease. We're also checking how smoking and e-cigarettes are used and how COVID-19 affects heart health.
#
# Our main goal is to extract actionable insights from this wealth of data. We want to make plans that focus on specific things to help reduce differences in heart health and make everyone's heart healthier in the adult population.

# %% [markdown]
# # Research and Analytical Questions:

# %% [markdown]
# These research questions are given by ChatGPT according to our problem statement.
#
# **Demographic Variation:**
#
# - How does the prevalence of heart disease and major risk factors vary across different demographic groups (sex, age, race/ethnicity)?
# Are there specific subgroups experiencing higher cardiovascular health disparities?
# Risk Factor Patterns:
#
# - What are the common patterns and combinations of major risk factors (high blood pressure, high cholesterol, smoking) within the dataset?
# How do these patterns relate to the overall cardiovascular health of individuals?
#
# **Impact of Chronic Conditions:**
#
# - Among individuals with chronic conditions (diabetes, asthma, COPD), how does the presence of these conditions correlate with heart disease prevalence?
# - Are certain chronic conditions more strongly associated with cardiovascular health disparities?
#
# **Behavioral Correlations:**
#
# - Explore the relationships between health behaviors (physical activity, sleep, alcohol consumption) and the prevalence of heart disease.
# - Identify key behavioral factors that may contribute to cardiovascular health disparities.
#
# **Effect of Mental Health on Heart Disease:**
#
# - Investigate the interplay between mental health (mental health days, depressive disorders) and heart disease.
# - Are individuals with certain mental health conditions more susceptible to cardiovascular issues?
#
# **Sensory Impairments and Cardiovascular Health:**
#
# - Analyze the impact of sensory impairments (deafness, vision difficulties) on heart disease prevalence and risk factors.
# - Explore if difficulty in concentration or physical activities differs based on sensory impairments.
#
# **Smoking and E-Cigarette Usage Patterns:**
#
# - Examine the patterns of smoking and e-cigarette usage and their correlation with heart disease prevalence.
# - Are there differences in cardiovascular health among smokers, former smokers, and non-smokers?
#
# **Vaccination and Preventive Measures:**
#
# - Assess the relationship between preventive measures (flu vaccination, pneumococcal vaccination) and heart disease prevalence.
# - Explore variations in vaccination rates among different demographic groups.
#
# **Impact of COVID-19:**
#
# - Explore the influence of COVID-19 on cardiovascular health, considering its association with heart disease prevalence and related risk factors.
# - Analyze if individuals who tested positive for COVID-19 exhibit distinctive patterns in cardiovascular health.
#
# **Some Other questions:**
# - Can you indicate which variables have a significant effect on the likelihood of heart disease?
# - How many people have at least 1 of 3 major risk factors for heart disease: high blood pressure, high cholesterol, and smoking.

# %% [markdown]
# # Importing Python Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Functions for plot and charts customizations

# %%
# Function for setting style and size of plot
def set_size_style(width, height, style):
    plt.figure(figsize=(width, height))
    sns.set_style(style)

# Function for customizating the plot
def customize_plot(plot, title:str, xlabel:str,  ylabel:str, title_font:int, label_font:int):
    plot.set_title(title, fontsize = title_font, weight='bold')
    plot.set_xlabel(xlabel, fontsize = label_font, weight='bold')
    plot.set_ylabel(ylabel, fontsize = label_font, weight='bold')

# %% [markdown]
# # Loading dataset

# %%
# Extract the given zip file if csv file is not present in the dataset folder
heart_data = pd.read_csv('heart_2022_with_nans.csv')

# %% [markdown]
# # Data Identification and Cleaning

# %%
heart_data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# 0         8.0          NaN             No  ...            NaN
# 1         6.0          NaN             No  ...           1.60
# 2         5.0          NaN             No  ...           1.57
# 3         7.0          NaN             No  ...           1.65
# 4         9.0          NaN             No  ...           1.57
#
#   WeightInKilograms    BMI AlcoholDrinkers HIVTesting FluVaxLast12  \
# 0               NaN    NaN              No         No          Yes
# 1             68.04  26.57              No         No           No
# 2             63.50  25.61              No         No           No
# 3             63.50  23.30              No         No          Yes
# 4             53.98  21.77             Yes         No           No
#
#   PneumoVaxEver                                  TetanusLast10Tdap  \
# 0            No  Yes, received tetanus shot but not sure what type
# 1            No  No, did not receive any tetanus shot in the pa...
# 2            No                                                NaN
# 3           Yes  No, did not receive any tetanus shot in the pa...
# 4           Yes  No, did not receive any tetanus shot in the pa...
#
#   HighRiskLastYear CovidPos
# 0               No       No
# 1               No       No
# 2               No      Yes
# 3               No       No
# 4               No       No
#
# [5 rows x 40 columns]

# %%
heart_data.shape
# Out:
# (445132, 40)

# %% [markdown]
# - There are 445132 rows and 40 columns in the dataset.

# %%
heart_data.tail()
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 445127  Virgin Islands  Female          Good                 0.0
# 445128  Virgin Islands  Female     Excellent                 2.0
# 445129  Virgin Islands  Female          Poor                30.0
# 445130  Virgin Islands    Male     Very good                 0.0
# 445131  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 445127               3.0  Within past 2 years (1 year but less than 2 ye...
# 445128               2.0  Within past year (anytime less than 12 months ...
# 445129              30.0                                5 or more years ago
# 445130               0.0  Within past year (anytime less than 12 months ...
# 445131               1.0                                                NaN
#
#        PhysicalActivities  SleepHours  RemovedTeeth HadHeartAttack  ...  \
# 445127                Yes         6.0  None of them             No  ...
# 445128                Yes         7.0  None of them             No  ...
# 445129                 No         5.0        1 to 5             No  ...
# 445130                 No         5.0  None of them            Yes  ...
# 445131                Yes         5.0  None of them             No  ...
#
#        HeightInMeters WeightInKilograms    BMI AlcoholDrinkers HIVTesting  \
# 445127           1.65             69.85  25.63             NaN        Yes
# 445128           1.70             83.01  28.66              No        Yes
# 445129           1.70             49.90  17.23             NaN         No
# 445130           1.83            108.86  32.55              No        Yes
# 445131           1.68             63.50  22.60             Yes         No
#
#        FluVaxLast12 PneumoVaxEver  \
# 445127           No            No
# 445128          Yes            No
# 445129           No            No
# 445130          Yes           Yes
# 445131           No            No
#
#                                         TetanusLast10Tdap HighRiskLastYear  \
# 445127  No, did not receive any tetanus shot in the pa...               No
# 445128  Yes, received tetanus shot but not sure what type               No
# 445129  No, did not receive any tetanus shot in the pa...               No
# 445130  No, did not receive any tetanus shot in the pa...               No
# 445131  Yes, received tetanus shot but not sure what type               No
#
#        CovidPos
# 445127      Yes
# 445128       No
# 445129       No
# 445130      Yes
# 445131       No
#
# [5 rows x 40 columns]

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      445132 non-null  object
#  1   Sex                        445132 non-null  object
#  2   GeneralHealth              443934 non-null  object
#  3   PhysicalHealthDays         434205 non-null  float64
#  4   MentalHealthDays           436065 non-null  float64
#  5   LastCheckupTime            436824 non-null  object
#  6   PhysicalActivities         444039 non-null  object
#  7   SleepHours                 439679 non-null  float64
#  8   RemovedTeeth               433772 non-null  object
#  9   HadHeartAttack             442067 non-null  object
#  10  HadAngina                  440727 non-null  object
#  11  HadStroke                  443575 non-null  object
#  12  HadAsthma                  443359 non-null  object
#  13  HadSkinCancer              441989 non-null  object
#  14  HadCOPD                    442913 non-null  object
#  15  HadDepressiveDisorder      442320 non-null  object
#  16  HadKidneyDisease           443206 non-null  object
#  17  HadArthritis               442499 non-null  object
#  18  HadDiabetes                444045 non-null  object
#  19  DeafOrHardOfHearing        424485 non-null  object
#  20  BlindOrVisionDifficulty    423568 non-null  object
#  21  DifficultyConcentrating    420892 non-null  object
#  22  DifficultyWalking          421120 non-null  object
#  23  DifficultyDressingBathing  421217 non-null  object
#  24  DifficultyErrands          419476 non-null  object
#  25  SmokerStatus               409670 non-null  object
#  26  ECigaretteUsage            409472 non-null  object
#  27  ChestScan                  389086 non-null  object
#  28  RaceEthnicityCategory      431075 non-null  object
#  29  AgeCategory                436053 non-null  object
#  30  HeightInMeters             416480 non-null  float64
#  31  WeightInKilograms          403054 non-null  float64
#  32  BMI                        396326 non-null  float64
#  33  AlcoholDrinkers            398558 non-null  object
#  34  HIVTesting                 379005 non-null  object
#  35  FluVaxLast12               398011 non-null  object
#  36  PneumoVaxEver              368092 non-null  object
#  37  TetanusLast10Tdap          362616 non-null  object
#  38  HighRiskLastYear           394509 non-null  object
#  39  CovidPos                   394368 non-null  object
# dtypes: float64(6), object(34)
# memory usage: 135.8+ MB

# %% [markdown]
# - Most of the columns(variables) are categorical and boolen.
# - Physical and mental health days, sleep hours, height, weight, BMI are numeric(float) values.

# %% [markdown]
# ### Handling null values

# %%
heart_data.isna().sum()
# Out:
# State                            0
# Sex                              0
# GeneralHealth                 1198
# PhysicalHealthDays           10927
# MentalHealthDays              9067
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                    5453
# RemovedTeeth                 11360
# HadHeartAttack                3065
# HadAngina                     4405
# HadStroke                     1557
# HadAsthma                     1773
# HadSkinCancer                 3143
# HadCOPD                       2219
# HadDepressiveDisorder         2812
# HadKidneyDisease              1926
# HadArthritis                  2633
# HadDiabetes                   1087
# DeafOrHardOfHearing          20647
# BlindOrVisionDifficulty      21564
# DifficultyConcentrating      24240
# DifficultyWalking            24012
# DifficultyDressingBathing    23915
# DifficultyErrands            25656
# SmokerStatus                 35462
# ECigaretteUsage              35660
# ChestScan                    56046
# RaceEthnicityCategory        14057
# AgeCategory                   9079
# HeightInMeters               28652
# WeightInKilograms            42078
# BMI                          48806
# AlcoholDrinkers              46574
# HIVTesting                   66127
# FluVaxLast12                 47121
# PneumoVaxEver                77040
# TetanusLast10Tdap            82516
# HighRiskLastYear             50623
# CovidPos                     50764
# dtype: int64

# %%
set_size_style(8,10,'whitegrid')
heart_data.isna().sum().plot(kind='barh')
# Out:
# <Axes: >

# %%
# Calculating percentage of null values in each column
null_values = round(heart_data.isna().sum()/heart_data.shape[0] * 100,2)

# %%
null_values
# Out:
# State                         0.00
# Sex                           0.00
# GeneralHealth                 0.27
# PhysicalHealthDays            2.45
# MentalHealthDays              2.04
# LastCheckupTime               1.87
# PhysicalActivities            0.25
# SleepHours                    1.23
# RemovedTeeth                  2.55
# HadHeartAttack                0.69
# HadAngina                     0.99
# HadStroke                     0.35
# HadAsthma                     0.40
# HadSkinCancer                 0.71
# HadCOPD                       0.50
# HadDepressiveDisorder         0.63
# HadKidneyDisease              0.43
# HadArthritis                  0.59
# HadDiabetes                   0.24
# DeafOrHardOfHearing           4.64
# BlindOrVisionDifficulty       4.84
# DifficultyConcentrating       5.45
# DifficultyWalking             5.39
# DifficultyDressingBathing     5.37
# DifficultyErrands             5.76
# SmokerStatus                  7.97
# ECigaretteUsage               8.01
# ChestScan                    12.59
# RaceEthnicityCategory         3.16
# AgeCategory                   2.04
# HeightInMeters                6.44
# WeightInKilograms             9.45
# BMI                          10.96
# AlcoholDrinkers              10.46
# HIVTesting                   14.86
# FluVaxLast12                 10.59
# PneumoVaxEver                17.31
# TetanusLast10Tdap            18.54
# HighRiskLastYear             11.37
# CovidPos                     11.40
# dtype: float64

# %%
# Dropping columns which we don't need.

heart_data = heart_data.drop(columns=['RemovedTeeth'])

# %%
heart_data.columns
# Out:
# Index(['State', 'Sex', 'GeneralHealth', 'PhysicalHealthDays',
#        'MentalHealthDays', 'LastCheckupTime', 'PhysicalActivities',
#        'SleepHours', 'HadHeartAttack', 'HadAngina', 'HadStroke', 'HadAsthma',
#        'HadSkinCancer', 'HadCOPD', 'HadDepressiveDisorder', 'HadKidneyDisease',
#        'HadArthritis', 'HadDiabetes', 'DeafOrHardOfHearing',
#        'BlindOrVisionDifficulty', 'DifficultyConcentrating',
#        'DifficultyWalking', 'DifficultyDressingBathing', 'DifficultyErrands',
#        'SmokerStatus', 'ECigaretteUsage', 'ChestScan', 'RaceEthnicityCategory',
#        'AgeCategory', 'HeightInMeters', 'WeightInKilograms', 'BMI',
#        'AlcoholDrinkers', 'HIVTesting', 'FluVaxLast12', 'PneumoVaxEver',
#        'TetanusLast10Tdap', 'HighRiskLastYear', 'CovidPos'],
#       dtype='object')

# %%
heart_data = heart_data.dropna( subset=['HadHeartAttack'] )
heart_data.shape
# Out:
# (442067, 39)

# %% [markdown]
# - Not removing more null values, as different columns have null values on different places, so removing a row based on a null value of a specific column can lead to loss of useful values in other columns.

# %%
heart_data.describe(include='object')
# Out:
#              State     Sex GeneralHealth  \
# count       442067  442067        440972
# unique          54       2             5
# top     Washington  Female     Very good
# freq         25997  234519        147967
#
#                                           LastCheckupTime PhysicalActivities  \
# count                                              434026             441095
# unique                                                  4                  2
# top     Within past year (anytime less than 12 months ...                Yes
# freq                                               348653             335778
#
#        HadHeartAttack HadAngina HadStroke HadAsthma HadSkinCancer  ...  \
# count          442067    438479    440997    440630        439303  ...
# unique              2         2         2         2             2  ...
# top                No        No        No        No            No  ...
# freq           416959    412331    422101    374481        404040  ...
#
#        ChestScan     RaceEthnicityCategory   AgeCategory AlcoholDrinkers  \
# count     386779                    428369        433260          396130
# unique         2                         5            13               2
# top           No  White only, Non-Hispanic  Age 65 to 69             Yes
# freq      222305                    318782         46808          210023
#
#        HIVTesting FluVaxLast12 PneumoVaxEver  \
# count      376757       395590        365857
# unique          2            2             2
# top            No          Yes            No
# freq       248383       208059        214407
#
#                                         TetanusLast10Tdap HighRiskLastYear  \
# count                                              360493           392082
# unique                                                  4                2
# top     No, did not receive any tetanus shot in the pa...               No
# freq                                               120549           374996
#
#        CovidPos
# count    391940
# unique        3
# top          No
# freq     268266
#
# [4 rows x 33 columns]

# %%
for col in heart_data.describe(include='object').columns:
    print('Column Name: ',col)
    print(heart_data[col].unique())
    print('-'*50)
# Out:
# Column Name:  State
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming' 'Guam' 'Puerto Rico'
#  'Virgin Islands']
# --------------------------------------------------
# Column Name:  Sex
# ['Female' 'Male']
# --------------------------------------------------
# Column Name:  GeneralHealth
# ['Very good' 'Excellent' 'Fair' 'Poor' 'Good' nan]
# --------------------------------------------------
# Column Name:  LastCheckupTime
# ['Within past year (anytime less than 12 months ago)' nan
#  'Within past 2 years (1 year but less than 2 years ago)'
#  'Within past 5 years (2 years but less than 5 years ago)'
#  '5 or more years ago']
# --------------------------------------------------
# Column Name:  PhysicalActivities
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadHeartAttack
# ['No' 'Yes']
# --------------------------------------------------
# Column Name:  HadAngina
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadStroke
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadAsthma
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadSkinCancer
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadCOPD
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadDepressiveDisorder
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadKidneyDisease
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadArthritis
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HadDiabetes
# ['Yes' 'No' 'No, pre-diabetes or borderline diabetes' nan
#  'Yes, but only during pregnancy (female)']
# --------------------------------------------------
# Column Name:  DeafOrHardOfHearing
# ['No' nan 'Yes']
# --------------------------------------------------
# Column Name:  BlindOrVisionDifficulty
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  DifficultyConcentrating
# ['No' nan 'Yes']
# --------------------------------------------------
# Column Name:  DifficultyWalking
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  DifficultyDressingBathing
# ['No' nan 'Yes']
# --------------------------------------------------
# Column Name:  DifficultyErrands
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  SmokerStatus
# ['Never smoked' 'Current smoker - now smokes some days' 'Former smoker'
#  nan 'Current smoker - now smokes every day']
# --------------------------------------------------
# Column Name:  ECigaretteUsage
# ['Not at all (right now)' 'Never used e-cigarettes in my entire life' nan
#  'Use them every day' 'Use them some days']
# --------------------------------------------------
# Column Name:  ChestScan
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  RaceEthnicityCategory
# ['White only, Non-Hispanic' 'Black only, Non-Hispanic'
#  'Other race only, Non-Hispanic' 'Multiracial, Non-Hispanic' nan
#  'Hispanic']
# --------------------------------------------------
# Column Name:  AgeCategory
# ['Age 80 or older' 'Age 55 to 59' nan 'Age 40 to 44' 'Age 75 to 79'
#  'Age 70 to 74' 'Age 65 to 69' 'Age 60 to 64' 'Age 50 to 54'
#  'Age 45 to 49' 'Age 35 to 39' 'Age 25 to 29' 'Age 30 to 34'
#  'Age 18 to 24']
# --------------------------------------------------
# Column Name:  AlcoholDrinkers
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  HIVTesting
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  FluVaxLast12
# ['Yes' 'No' nan]
# --------------------------------------------------
# Column Name:  PneumoVaxEver
# ['No' 'Yes' nan]
# --------------------------------------------------
# Column Name:  TetanusLast10Tdap
# ['Yes, received tetanus shot but not sure what type'
#  'No, did not receive any tetanus shot in the past 10 years' nan
#  'Yes, received Tdap' 'Yes, received tetanus shot, but not Tdap']
# --------------------------------------------------
# Column Name:  HighRiskLastYear
# ['No' nan 'Yes']
# --------------------------------------------------
# Column Name:  CovidPos
# ['No' 'Yes' nan
#  'Tested positive using home test without a health professional']
# --------------------------------------------------

# %% [markdown]
# - Some columns have large categorical text values, so need to make it short but understandable.

# %%
heart_data['LastCheckupTime'].replace({'Within past year (anytime less than 12 months ago)' : 'Within past year',
                                       'Within past 2 years (1 year but less than 2 years ago)' : 'Within past 2 years',
                                       'Within past 5 years (2 years but less than 5 years ago)' : 'Within past 5 years'}, inplace=True)

heart_data['LastCheckupTime'].unique()
# Out:
# array(['Within past year', nan, 'Within past 2 years',
#        'Within past 5 years', '5 or more years ago'], dtype=object)

# %%
heart_data['HadDiabetes'].replace({'No, pre-diabetes or borderline diabetes' : 'Borderline',
                                   'Yes, but only during pregnancy (female)' : 'During Pregnancy'}, inplace=True)

heart_data['HadDiabetes'].unique()
# Out:
# array(['Yes', 'No', 'Borderline', nan, 'During Pregnancy'], dtype=object)

# %%
heart_data['SmokerStatus'].replace({'Current smoker - now smokes some days' : 'Current smoker(Some days)',
                                    'Current smoker - now smokes every day' : 'Current smoker(Every day)'}, inplace=True)

heart_data['SmokerStatus'].unique()
# Out:
# array(['Never smoked', 'Current smoker(Some days)', 'Former smoker', nan,
#        'Current smoker(Every day)'], dtype=object)

# %%
heart_data['ECigaretteUsage'].replace({'Not at all (right now)' : 'Not at all',
                                        'Never used e-cigarettes in my entire life' : 'Never',
                                        'Use them every day' : 'Everyday',
                                        'Use them some days' : 'Somedays'}, inplace=True)

heart_data['ECigaretteUsage'].unique()
# Out:
# array(['Not at all', 'Never', nan, 'Everyday', 'Somedays'], dtype=object)

# %%
heart_data['RaceEthnicityCategory'].replace({'White only, Non-Hispanic' : 'White',
                                             'Black only, Non-Hispanic' : 'Black',
                                             'Other race only, Non-Hispanic' : 'Other Race',
                                             'Multiracial, Non-Hispanic' : 'Multi Racial'}, inplace=True)

heart_data['RaceEthnicityCategory'].unique()
# Out:
# array(['White', 'Black', 'Other Race', 'Multi Racial', nan, 'Hispanic'],
#       dtype=object)

# %%
heart_data['AgeCategory'].replace({'Age 80 or older' : '80+'}, inplace=True)

for value in heart_data['AgeCategory'].unique()[1:]:
    value = str(value)
    if value != 'nan':
        cat_value = value.split(" ")
        heart_data['AgeCategory'].replace({value : cat_value[1]+"-"+cat_value[3]}, inplace=True)
        
heart_data['AgeCategory'].unique()
# Out:
# array(['80+', '55-59', nan, '40-44', '75-79', '70-74', '65-69', '60-64',
#        '50-54', '45-49', '35-39', '25-29', '30-34', '18-24'], dtype=object)

# %%
heart_data['TetanusLast10Tdap'].replace({'Yes, received tetanus shot but not sure what type' : 'Yes, type not sure',
                                         'No, did not receive any tetanus shot in the past 10 years' : 'No',
                                         'Yes, received Tdap' : 'Yes',
                                         'Yes, received tetanus shot, but not Tdap' : 'Yes, not Tdap'}, inplace=True)

heart_data['TetanusLast10Tdap'].unique()
# Out:
# array(['Yes, type not sure', 'No', nan, 'Yes', 'Yes, not Tdap'],
#       dtype=object)

# %%
heart_data['CovidPos'].replace({'Tested positive using home test without a health professional' : 'Yes, with home test'}, inplace=True)

heart_data['CovidPos'].unique()
# Out:
# array(['No', 'Yes', nan, 'Yes, with home test'], dtype=object)

# %% [markdown]
# - Now all categorical values are shortened and easy to understand.

# %%
heart_data.describe(include='object')
# Out:
#              State     Sex GeneralHealth   LastCheckupTime PhysicalActivities  \
# count       442067  442067        440972            434026             441095
# unique          54       2             5                 4                  2
# top     Washington  Female     Very good  Within past year                Yes
# freq         25997  234519        147967            348653             335778
#
#        HadHeartAttack HadAngina HadStroke HadAsthma HadSkinCancer  ...  \
# count          442067    438479    440997    440630        439303  ...
# unique              2         2         2         2             2  ...
# top                No        No        No        No            No  ...
# freq           416959    412331    422101    374481        404040  ...
#
#        ChestScan RaceEthnicityCategory AgeCategory AlcoholDrinkers HIVTesting  \
# count     386779                428369      433260          396130     376757
# unique         2                     5          13               2          2
# top           No                 White       65-69             Yes         No
# freq      222305                318782       46808          210023     248383
#
#        FluVaxLast12 PneumoVaxEver TetanusLast10Tdap HighRiskLastYear CovidPos
# count        395590        365857            360493           392082   391940
# unique            2             2                 4                2        3
# top             Yes            No                No               No       No
# freq         208059        214407            120549           374996   268266
#
# [4 rows x 33 columns]

# %% [markdown]
# ### Dropping duplicate rows

# %%
heart_data[heart_data.duplicated()]
# Out:
#               State     Sex GeneralHealth  PhysicalHealthDays  \
# 7310         Alaska    Male     Very good                 0.0
# 11503       Arizona  Female     Excellent                 0.0
# 23991      Arkansas    Male     Excellent                 0.0
# 28206    California    Male     Excellent                 0.0
# 29339    California    Male     Excellent                 0.0
# ...             ...     ...           ...                 ...
# 431068    Wisconsin    Male          Good                 0.0
# 431351    Wisconsin    Male          Good                 0.0
# 431653    Wisconsin    Male     Excellent                 0.0
# 433508      Wyoming  Female          Good                 0.0
# 440127  Puerto Rico    Male     Excellent                 0.0
#
#         MentalHealthDays   LastCheckupTime PhysicalActivities  SleepHours  \
# 7310                 0.0  Within past year                Yes         7.0
# 11503                0.0  Within past year                Yes         7.0
# 23991                0.0  Within past year                Yes         7.0
# 28206                0.0  Within past year                Yes         7.0
# 29339                0.0  Within past year                Yes         7.0
# ...                  ...               ...                ...         ...
# 431068               0.0  Within past year                Yes         7.0
# 431351               0.0  Within past year                Yes         7.0
# 431653               0.0  Within past year                Yes         8.0
# 433508               0.0  Within past year                Yes         8.0
# 440127               0.0  Within past year                Yes         8.0
#
#        HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms    BMI  \
# 7310               No        No  ...            NaN               NaN    NaN
# 11503              No        No  ...           1.63              56.7  21.46
# 23991              No        No  ...            NaN               NaN    NaN
# 28206              No        No  ...            NaN               NaN    NaN
# 29339              No        No  ...            NaN               NaN    NaN
# ...               ...       ...  ...            ...               ...    ...
# 431068             No        No  ...            NaN               NaN    NaN
# 431351             No        No  ...            NaN               NaN    NaN
# 431653             No        No  ...            NaN               NaN    NaN
# 433508             No        No  ...            NaN               NaN    NaN
# 440127             No        No  ...            NaN               NaN    NaN
#
#        AlcoholDrinkers HIVTesting FluVaxLast12 PneumoVaxEver  \
# 7310               NaN        NaN          NaN           NaN
# 11503              Yes         No          Yes           Yes
# 23991              NaN        NaN          NaN           NaN
# 28206              NaN        NaN          NaN           NaN
# 29339              NaN        NaN          NaN           NaN
# ...                ...        ...          ...           ...
# 431068             NaN        NaN          NaN           NaN
# 431351             NaN        NaN          NaN           NaN
# 431653             NaN        NaN          NaN           NaN
# 433508             NaN        NaN          NaN           NaN
# 440127             NaN        NaN          NaN           NaN
#
#        TetanusLast10Tdap HighRiskLastYear CovidPos
# 7310                 NaN              NaN      NaN
# 11503                Yes               No       No
# 23991                NaN              NaN      NaN
# 28206                NaN              NaN      NaN
# 29339                NaN              NaN      NaN
# ...                  ...              ...      ...
# 431068               NaN              NaN      NaN
# 431351               NaN              NaN      NaN
# 431653               NaN              NaN      NaN
# 433508               NaN              NaN      NaN
# 440127               NaN              NaN      NaN
#
# [253 rows x 39 columns]

# %%
heart_data.drop_duplicates(inplace=True)

# %% [markdown]
# ### Checking columns with numeric data and handling outliers.

# %%
# Display brief summary statistics
heart_data.describe()
# Out:
#        PhysicalHealthDays  MentalHealthDays     SleepHours  HeightInMeters  \
# count       431217.000000     433022.000000  436618.000000   413912.000000
# mean             4.325105          4.373942       7.023130        1.702759
# std              8.664222          8.374511       1.496724        0.107142
# min              0.000000          0.000000       1.000000        0.910000
# 25%              0.000000          0.000000       6.000000        1.630000
# 50%              0.000000          0.000000       7.000000        1.700000
# 75%              3.000000          5.000000       8.000000        1.780000
# max             30.000000         30.000000      24.000000        2.410000
#
#        WeightInKilograms            BMI
# count      400587.000000  393943.000000
# mean           83.077572      28.527887
# std            21.439392       6.551014
# min            22.680000      12.020000
# 25%            68.040000      24.130000
# 50%            80.740000      27.440000
# 75%            95.250000      31.740000
# max           292.570000      99.640000

# %%
for col in heart_data.describe().columns:
    set_size_style(16,2,'ticks')
    sns.boxplot(data=heart_data, x=col)
    plt.show()

# %% [markdown]
# - We will have a closer view of outlier values of height, weight and sleep hours as some values don't looks normal.

# %%
# Function for extracting outliers in column of dataframe
def get_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3-Q1
    
    lower_limit = Q1 - (IQR * 1.5)
    upper_limit = Q3 + (IQR * 1.5)
    
    outliers = df[(df[column] < lower_limit) | (df[column] > upper_limit)]
    
    return outliers, lower_limit, upper_limit

# %%
sleep_hours_outliers, lower_sleep, upper_sleep = get_outliers(heart_data, 'SleepHours')
sleep_hours_outliers
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 88             Alabama  Female     Excellent                 0.0
# 95             Alabama    Male          Poor                 NaN
# 118            Alabama  Female          Poor                30.0
# 127            Alabama    Male     Very good                 0.0
# 208            Alabama  Female          Poor                25.0
# ...                ...     ...           ...                 ...
# 444948  Virgin Islands  Female          Fair                 2.0
# 445066  Virgin Islands    Male     Very good                 NaN
# 445103  Virgin Islands  Female          Good                10.0
# 445108  Virgin Islands  Female          Good                 5.0
# 445113  Virgin Islands  Female          Good                 0.0
#
#         MentalHealthDays      LastCheckupTime PhysicalActivities  SleepHours  \
# 88                   0.0  Within past 2 years                 No         1.0
# 95                   0.0     Within past year                Yes        12.0
# 118                 30.0     Within past year                 No        18.0
# 127                  2.0     Within past year                Yes        12.0
# 208                  0.0     Within past year                Yes        12.0
# ...                  ...                  ...                ...         ...
# 444948               1.0     Within past year                Yes        18.0
# 445066               0.0     Within past year                Yes        20.0
# 445103               0.0     Within past year                 No        12.0
# 445108               NaN     Within past year                Yes        18.0
# 445113               0.0     Within past year                Yes        12.0
#
#        HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms    BMI  \
# 88                 No        No  ...           1.60             54.43  21.26
# 95                 No        No  ...           1.83            106.59  31.87
# 118               Yes       Yes  ...           1.50             47.17  21.01
# 127                No        No  ...           1.73             50.80  17.03
# 208                No        No  ...           1.63            136.08  51.49
# ...               ...       ...  ...            ...               ...    ...
# 444948             No        No  ...           1.65             99.79  36.61
# 445066             No        No  ...           1.80             86.18  26.50
# 445103            Yes        No  ...            NaN               NaN    NaN
# 445108             No        No  ...           1.55             58.97  24.56
# 445113             No        No  ...           1.65             52.16  19.14
#
#        AlcoholDrinkers HIVTesting FluVaxLast12 PneumoVaxEver  \
# 88                  No         No           No            No
# 95                 Yes         No          Yes           Yes
# 118                 No         No           No            No
# 127                 No        Yes          Yes           Yes
# 208                 No         No          Yes           Yes
# ...                ...        ...          ...           ...
# 444948             Yes         No          Yes            No
# 445066              No         No          Yes           Yes
# 445103             NaN        NaN          NaN           NaN
# 445108              No         No          Yes            No
# 445113              No         No           No           Yes
#
#          TetanusLast10Tdap HighRiskLastYear CovidPos
# 88                      No               No       No
# 95           Yes, not Tdap               No       No
# 118                     No               No       No
# 127     Yes, type not sure               No       No
# 208                     No               No      Yes
# ...                    ...              ...      ...
# 444948                  No               No       No
# 445066  Yes, type not sure               No       No
# 445103                 NaN              NaN      NaN
# 445108  Yes, type not sure               No       No
# 445113                 Yes               No       No
#
# [7107 rows x 39 columns]

# %%
print(f"Lower Limit(SleepHours):{lower_sleep})\nUpper Limit(SleepHours):{upper_sleep})")
# Out:
# Lower Limit(SleepHours):3.0)
# Upper Limit(SleepHours):11.0)

# %% [markdown]
# - The Upper Limit of SleepHours is questionnable so we will adjust this according to our own assumption

# %%
heart_data[heart_data['SleepHours'] < lower_sleep]
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 88             Alabama  Female     Excellent                 0.0
# 429            Alabama    Male          Poor                10.0
# 890            Alabama  Female          Fair                 NaN
# 935            Alabama    Male          Good                 5.0
# 1228           Alabama    Male     Excellent                 4.0
# ...                ...     ...           ...                 ...
# 444551  Virgin Islands  Female          Fair                25.0
# 444600  Virgin Islands  Female          Poor                 7.0
# 444617  Virgin Islands    Male     Excellent                 0.0
# 444797  Virgin Islands  Female          Fair                 1.0
# 444907  Virgin Islands  Female     Excellent                10.0
#
#         MentalHealthDays      LastCheckupTime PhysicalActivities  SleepHours  \
# 88                   0.0  Within past 2 years                 No         1.0
# 429                  4.0     Within past year                 No         2.0
# 890                  5.0     Within past year                 No         2.0
# 935                  0.0     Within past year                Yes         2.0
# 1228                14.0  Within past 5 years                Yes         2.0
# ...                  ...                  ...                ...         ...
# 444551              10.0     Within past year                Yes         1.0
# 444600               7.0     Within past year                Yes         1.0
# 444617               0.0  Within past 5 years                Yes         1.0
# 444797               0.0     Within past year                Yes         2.0
# 444907              10.0     Within past year                Yes         1.0
#
#        HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms    BMI  \
# 88                 No        No  ...           1.60             54.43  21.26
# 429               Yes       Yes  ...           1.85             75.75  22.03
# 890                No        No  ...           1.70            120.20  41.50
# 935                No        No  ...           1.78               NaN    NaN
# 1228               No        No  ...           1.83             77.11  23.06
# ...               ...       ...  ...            ...               ...    ...
# 444551             No       Yes  ...           1.60             80.29  31.35
# 444600             No        No  ...           1.52               NaN    NaN
# 444617             No        No  ...           1.60             95.25  37.20
# 444797             No        No  ...           1.60             83.91  32.77
# 444907             No        No  ...           1.65             46.27  16.97
#
#        AlcoholDrinkers HIVTesting FluVaxLast12 PneumoVaxEver  \
# 88                  No         No           No            No
# 429                 No         No          Yes           Yes
# 890                 No         No           No            No
# 935                 No        Yes          Yes           Yes
# 1228               Yes         No           No            No
# ...                ...        ...          ...           ...
# 444551             Yes        Yes          Yes           Yes
# 444600              No         No           No            No
# 444617             Yes        Yes          Yes            No
# 444797              No        Yes           No            No
# 444907              No         No          Yes            No
#
#          TetanusLast10Tdap HighRiskLastYear CovidPos
# 88                      No               No       No
# 429     Yes, type not sure               No       No
# 890                     No               No       No
# 935                    Yes               No       No
# 1228    Yes, type not sure               No       No
# ...                    ...              ...      ...
# 444551                 Yes               No       No
# 444600       Yes, not Tdap               No      Yes
# 444617       Yes, not Tdap               No       No
# 444797                 NaN               No       No
# 444907                  No               No       No
#
# [2634 rows x 39 columns]

# %%
heart_data[heart_data['SleepHours'] > 13]
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 118            Alabama  Female          Poor                30.0
# 623            Alabama  Female          Fair                 0.0
# 676            Alabama  Female          Poor                30.0
# 1205           Alabama  Female     Very good                 0.0
# 1320           Alabama  Female          Good                15.0
# ...                ...     ...           ...                 ...
# 444751  Virgin Islands  Female     Very good                 0.0
# 444778  Virgin Islands  Female          Fair                 7.0
# 444948  Virgin Islands  Female          Fair                 2.0
# 445066  Virgin Islands    Male     Very good                 NaN
# 445108  Virgin Islands  Female          Good                 5.0
#
#         MentalHealthDays      LastCheckupTime PhysicalActivities  SleepHours  \
# 118                 30.0     Within past year                 No        18.0
# 623                  0.0     Within past year                 No        18.0
# 676                 10.0  Within past 2 years                 No        18.0
# 1205                15.0     Within past year                Yes        16.0
# 1320                15.0     Within past year                 No        15.0
# ...                  ...                  ...                ...         ...
# 444751               0.0                  NaN                Yes        20.0
# 444778               0.0     Within past year                 No        15.0
# 444948               1.0     Within past year                Yes        18.0
# 445066               0.0     Within past year                Yes        20.0
# 445108               NaN     Within past year                Yes        18.0
#
#        HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms    BMI  \
# 118               Yes       Yes  ...           1.50             47.17  21.01
# 623                No        No  ...           1.63             81.65  30.90
# 676                No        No  ...           1.70             93.89  32.42
# 1205               No        No  ...           1.63             85.73  32.44
# 1320               No        No  ...           1.63             86.18  32.61
# ...               ...       ...  ...            ...               ...    ...
# 444751             No        No  ...           1.68               NaN    NaN
# 444778             No        No  ...           1.60             58.97  23.03
# 444948             No        No  ...           1.65             99.79  36.61
# 445066             No        No  ...           1.80             86.18  26.50
# 445108             No        No  ...           1.55             58.97  24.56
#
#        AlcoholDrinkers HIVTesting FluVaxLast12 PneumoVaxEver  \
# 118                 No         No           No            No
# 623                NaN        NaN          NaN           NaN
# 676                 No         No           No           Yes
# 1205               NaN        NaN          NaN           NaN
# 1320                No         No          Yes           Yes
# ...                ...        ...          ...           ...
# 444751              No        Yes           No            No
# 444778              No        Yes           No           Yes
# 444948             Yes         No          Yes            No
# 445066              No         No          Yes           Yes
# 445108              No         No          Yes            No
#
#          TetanusLast10Tdap HighRiskLastYear CovidPos
# 118                     No               No       No
# 623                    NaN              NaN      NaN
# 676                     No               No       No
# 1205                   NaN              NaN      NaN
# 1320                   Yes               No       No
# ...                    ...              ...      ...
# 444751                  No               No       No
# 444778                  No               No       No
# 444948                  No               No       No
# 445066  Yes, type not sure               No       No
# 445108  Yes, type not sure               No       No
#
# [1357 rows x 39 columns]

# %% [markdown]
# - Dropping rows with outlier values in sleeping hours as data seems incorrect, some people have excellent health condition with sleeping more than 13 hours and also less than 3 hours, that seems to be incorrect readings.

# %%
heart_data.shape
# Out:
# (441814, 39)

# %%
# Dropping records with sleep less than 3 hours
heart_data = heart_data.drop(heart_data[heart_data['SleepHours'] < lower_sleep].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (439180, 39)

# %%
# Dropping record with sleep greater than 16 hourss
heart_data = heart_data.drop(heart_data[heart_data['SleepHours'] > 13].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (437823, 39)

# %%
sns.boxplot(data=heart_data, x='SleepHours')
# Out:
# <Axes: xlabel='SleepHours'>

# %%
height_outliers, lower_height, upper_height = get_outliers(heart_data, 'HeightInMeters')
height_outliers
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 551            Alabama  Female          Fair                30.0
# 860            Alabama  Female          Poor                30.0
# 887            Alabama  Female          Fair                30.0
# 1510           Alabama    Male          Good                 0.0
# 1527           Alabama    Male     Very good                 0.0
# ...                ...     ...           ...                 ...
# 437400  Virgin Islands    Male     Very good                 0.0
# 437426  Virgin Islands    Male           NaN                 1.0
# 437552  Virgin Islands    Male          Poor                30.0
# 437637  Virgin Islands  Female          Fair                 0.0
# 437800  Virgin Islands  Female          Fair                 0.0
#
#         MentalHealthDays      LastCheckupTime PhysicalActivities  SleepHours  \
# 551                  0.0     Within past year                 No         6.0
# 860                 30.0     Within past year                 No         9.0
# 887                  0.0     Within past year                 No         8.0
# 1510                 0.0     Within past year                 No         7.0
# 1527                 0.0  Within past 5 years                 No         8.0
# ...                  ...                  ...                ...         ...
# 437400               0.0  5 or more years ago                Yes         7.0
# 437426               0.0  Within past 5 years                Yes         NaN
# 437552              25.0     Within past year                 No         5.0
# 437637               0.0     Within past year                Yes         8.0
# 437800               0.0     Within past year                Yes         7.0
#
#        HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms    BMI  \
# 551               Yes        No  ...           1.24             86.18  55.64
# 860               Yes       Yes  ...           1.22            136.08  91.55
# 887                No        No  ...           1.22             44.91  30.21
# 1510               No        No  ...           2.03             70.31  17.03
# 1527               No        No  ...           2.01             95.25  23.66
# ...               ...       ...  ...            ...               ...    ...
# 437400             No        No  ...           2.13             68.04  14.95
# 437426             No        No  ...           1.27             63.50  39.37
# 437552            Yes       Yes  ...           2.01            106.14  26.36
# 437637             No        No  ...           1.35             63.05  34.79
# 437800            Yes       NaN  ...           1.35             36.29  20.02
#
#        AlcoholDrinkers HIVTesting FluVaxLast12 PneumoVaxEver  \
# 551                 No         No          Yes           Yes
# 860                 No         No          Yes           Yes
# 887                 No         No           No           Yes
# 1510                No         No           No            No
# 1527               Yes        Yes          Yes            No
# ...                ...        ...          ...           ...
# 437400              No        Yes           No            No
# 437426              No         No           No           Yes
# 437552             Yes        Yes           No           Yes
# 437637              No         No          Yes            No
# 437800              No         No           No            No
#
#          TetanusLast10Tdap HighRiskLastYear             CovidPos
# 551                     No               No                  NaN
# 860                     No               No                   No
# 887                    Yes               No                   No
# 1510                    No               No                   No
# 1527                   Yes               No                   No
# ...                    ...              ...                  ...
# 437400  Yes, type not sure               No                   No
# 437426                  No               No                   No
# 437552  Yes, type not sure               No  Yes, with home test
# 437637                  No               No                   No
# 437800                  No               No                   No
#
# [1497 rows x 39 columns]

# %%
print(f"Lower Limit(Height):{lower_height})\nUpper Limit(Height):{upper_height})")
# Out:
# Lower Limit(Height):1.4049999999999998)
# Upper Limit(Height):2.0050000000000003)

# %% [markdown]
# - The lower limit seems a bit strict because some adults can be shorter than 1.4 meters. Similarly, the upper limit might be too narrow because some people can be taller than 2 meters. We'll change these limits based on our own ideas or assumptions.

# %%
heart_data[heart_data['HeightInMeters'] < 1.3]
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 551            Alabama  Female          Fair                30.0
# 860            Alabama  Female          Poor                30.0
# 887            Alabama  Female          Fair                30.0
# 2341           Alabama  Female          Good                 0.0
# 8918            Alaska    Male          Fair                 0.0
# ...                ...     ...           ...                 ...
# 433599     Puerto Rico  Female          Good                14.0
# 434353     Puerto Rico  Female          Fair                 0.0
# 435575     Puerto Rico  Female          Fair                 0.0
# 436612  Virgin Islands  Female          Good                 0.0
# 437426  Virgin Islands    Male           NaN                 1.0
#
#         MentalHealthDays      LastCheckupTime PhysicalActivities  SleepHours  \
# 551                  0.0     Within past year                 No         6.0
# 860                 30.0     Within past year                 No         9.0
# 887                  0.0     Within past year                 No         8.0
# 2341                 0.0     Within past year                Yes         7.0
# 8918                 1.0     Within past year                 No         6.0
# ...                  ...                  ...                ...         ...
# 433599              14.0     Within past year                Yes         5.0
# 434353               0.0     Within past year                 No         5.0
# 435575               0.0     Within past year                 No         8.0
# 436612               0.0                  NaN                Yes         8.0
# 437426               0.0  Within past 5 years                Yes         NaN
#
#        HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms    BMI  \
# 551               Yes        No  ...           1.24             86.18  55.64
# 860               Yes       Yes  ...           1.22            136.08  91.55
# 887                No        No  ...           1.22             44.91  30.21
# 2341               No        No  ...           1.22             45.81  30.82
# 8918               No       Yes  ...           0.91             95.25    NaN
# ...               ...       ...  ...            ...               ...    ...
# 433599             No        No  ...           1.27             45.36  28.12
# 434353             No        No  ...           1.22             74.39  50.04
# 435575             No        No  ...           1.27             73.03  45.28
# 436612             No       Yes  ...           1.22               NaN    NaN
# 437426             No        No  ...           1.27             63.50  39.37
#
#        AlcoholDrinkers HIVTesting FluVaxLast12 PneumoVaxEver  \
# 551                 No         No          Yes           Yes
# 860                 No         No          Yes           Yes
# 887                 No         No           No           Yes
# 2341                No         No           No            No
# 8918                No         No          Yes           Yes
# ...                ...        ...          ...           ...
# 433599              No         No           No            No
# 434353              No        Yes          Yes           NaN
# 435575              No        Yes           No           Yes
# 436612             NaN        NaN          NaN           NaN
# 437426              No         No           No           Yes
#
#          TetanusLast10Tdap HighRiskLastYear CovidPos
# 551                     No               No      NaN
# 860                     No               No       No
# 887                    Yes               No       No
# 2341                    No              Yes      Yes
# 8918                   Yes               No       No
# ...                    ...              ...      ...
# 433599                  No               No       No
# 434353  Yes, type not sure               No       No
# 435575  Yes, type not sure               No       No
# 436612                 NaN              NaN      NaN
# 437426                  No               No       No
#
# [260 rows x 39 columns]

# %%
heart_data[heart_data['HeightInMeters'] > 2.1]
# Out:
#                  State   Sex GeneralHealth  PhysicalHealthDays  \
# 5192            Alaska  Male     Excellent                 0.0
# 8350            Alaska  Male     Very good                 0.0
# 8842            Alaska  Male          Good                20.0
# 9490            Alaska  Male          Good                10.0
# 22984         Arkansas  Male          Fair                 0.0
# ...                ...   ...           ...                 ...
# 400347      Washington  Male     Very good                 0.0
# 400511      Washington  Male     Excellent                 0.0
# 404276      Washington  Male     Very good                 0.0
# 428924            Guam  Male          Poor                30.0
# 437400  Virgin Islands  Male     Very good                 0.0
#
#         MentalHealthDays      LastCheckupTime PhysicalActivities  SleepHours  \
# 5192                 5.0  Within past 5 years                Yes         7.0
# 8350                 0.0     Within past year                Yes         7.0
# 8842                19.0  Within past 2 years                Yes         5.0
# 9490                15.0     Within past year                 No         7.0
# 22984                0.0     Within past year                Yes         6.0
# ...                  ...                  ...                ...         ...
# 400347               0.0     Within past year                Yes         8.0
# 400511               0.0  Within past 2 years                Yes         6.0
# 404276               0.0     Within past year                Yes         8.0
# 428924               0.0     Within past year                 No         8.0
# 437400               0.0  5 or more years ago                Yes         7.0
#
#        HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms    BMI  \
# 5192               No        No  ...           2.11             70.31  15.82
# 8350               No        No  ...           2.16             83.91  18.00
# 8842               No        No  ...           2.26             92.53  18.11
# 9490               No       Yes  ...           2.16             88.45  18.98
# 22984              No        No  ...           2.13            181.44  39.86
# ...               ...       ...  ...            ...               ...    ...
# 400347             No        No  ...           2.13             72.57  15.94
# 400511             No        No  ...           2.34             70.31  12.88
# 404276             No        No  ...           2.21            137.89  28.24
# 428924             No        No  ...           2.16             77.56  16.64
# 437400             No        No  ...           2.13             68.04  14.95
#
#        AlcoholDrinkers HIVTesting FluVaxLast12 PneumoVaxEver  \
# 5192               Yes         No          Yes           NaN
# 8350               Yes        NaN          Yes           Yes
# 8842                No         No           No            No
# 9490                No        Yes           No            No
# 22984               No        Yes          Yes           Yes
# ...                ...        ...          ...           ...
# 400347              No         No          Yes           Yes
# 400511             Yes         No           No            No
# 404276             Yes         No          Yes           Yes
# 428924              No         No           No            No
# 437400              No        Yes           No            No
#
#          TetanusLast10Tdap HighRiskLastYear CovidPos
# 5192                   NaN               No       No
# 8350    Yes, type not sure               No       No
# 8842                    No               No      Yes
# 9490                   Yes               No      Yes
# 22984   Yes, type not sure               No      Yes
# ...                    ...              ...      ...
# 400347  Yes, type not sure              Yes       No
# 400511       Yes, not Tdap               No       No
# 404276  Yes, type not sure               No       No
# 428924  Yes, type not sure               No       No
# 437400  Yes, type not sure               No       No
#
# [101 rows x 39 columns]

# %% [markdown]
# - Dropping rows with outlier values in HeightInMeters as data seems incorrect.

# %%
heart_data.shape
# Out:
# (437823, 39)

# %%
# Dropping records with height less than 1.3 meters
heart_data = heart_data.drop(heart_data[heart_data['HeightInMeters'] < 1.3].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (437563, 39)

# %%
# Dropping records with height greater than 2.1 meters
heart_data = heart_data.drop(heart_data[heart_data['HeightInMeters'] > 2.1].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (437462, 39)

# %%
sns.boxplot(data=heart_data, x='HeightInMeters')
# Out:
# <Axes: xlabel='HeightInMeters'>

# %%
weight_outliers, lower_weight, upper_weight = get_outliers(heart_data, 'WeightInKilograms')
weight_outliers
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 48             Alabama  Female          Good                 0.0
# 140            Alabama  Female          Fair                30.0
# 156            Alabama    Male          Good                 0.0
# 206            Alabama  Female          Poor                25.0
# 333            Alabama  Female          Fair                30.0
# ...                ...     ...           ...                 ...
# 437020  Virgin Islands  Female          Good                 0.0
# 437194  Virgin Islands    Male          Good                 5.0
# 437322  Virgin Islands    Male          Good                 5.0
# 437342  Virgin Islands  Female          Good                 2.0
# 437412  Virgin Islands  Female          Good                 2.0
#
#         MentalHealthDays      LastCheckupTime PhysicalActivities  SleepHours  \
# 48                  18.0     Within past year                 No         8.0
# 140                 20.0     Within past year                Yes         5.0
# 156                  0.0     Within past year                 No         8.0
# 206                  0.0     Within past year                Yes        12.0
# 333                  8.0     Within past year                Yes         7.0
# ...                  ...                  ...                ...         ...
# 437020               0.0     Within past year                Yes         7.0
# 437194               0.0     Within past year                 No         6.0
# 437322               0.0     Within past year                Yes         6.0
# 437342               NaN     Within past year                 No         NaN
# 437412              10.0  Within past 2 years                Yes         7.0
#
#        HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms    BMI  \
# 48                 No        No  ...           1.73            136.08  45.61
# 140                No        No  ...           1.60            145.15  56.68
# 156                No        No  ...           1.83            158.76  47.47
# 206                No        No  ...           1.63            136.08  51.49
# 333                No        No  ...           1.85            136.08  39.58
# ...               ...       ...  ...            ...               ...    ...
# 437020             No        No  ...           1.73            136.08  45.61
# 437194             No        No  ...           1.83            158.76  47.47
# 437322             No        No  ...           1.83            170.10  50.86
# 437342             No        No  ...           1.68            163.29  58.10
# 437412             No        No  ...           1.73            142.88  47.90
#
#        AlcoholDrinkers HIVTesting FluVaxLast12 PneumoVaxEver  \
# 48                  No        Yes          Yes            No
# 140                 No        Yes           No            No
# 156                 No         No          Yes           NaN
# 206                 No         No          Yes           Yes
# 333                 No         No          Yes           Yes
# ...                ...        ...          ...           ...
# 437020              No        Yes           No            No
# 437194             Yes        Yes           No            No
# 437322             Yes        Yes           No           NaN
# 437342              No        Yes          Yes            No
# 437412             Yes        Yes           No            No
#
#          TetanusLast10Tdap HighRiskLastYear CovidPos
# 48                      No               No       No
# 140                    Yes               No       No
# 156                     No               No       No
# 206                     No               No      Yes
# 333                     No               No       No
# ...                    ...              ...      ...
# 437020                  No              Yes       No
# 437194  Yes, type not sure               No      Yes
# 437322  Yes, type not sure               No       No
# 437342                 NaN              Yes       No
# 437412  Yes, type not sure               No       No
#
# [9429 rows x 39 columns]

# %%
print(f"Lower Limit(Weight):{lower_weight})\nUpper Limit(Weight):{upper_weight})")
# Out:
# Lower Limit(Weight):27.225000000000016)
# Upper Limit(Weight):136.065)

# %% [markdown]
# - Again we will adjust the upper limit and lower limit.

# %%
heart_data[heart_data['WeightInKilograms'] < 40]
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 49             Alabama  Female          Good                 0.0
# 707            Alabama  Female          Fair                15.0
# 794            Alabama  Female          Fair                30.0
# 1135           Alabama  Female          Fair                 NaN
# 3426           Alabama  Female          Good                 0.0
# ...                ...     ...           ...                 ...
# 435171     Puerto Rico  Female          Fair                28.0
# 435574     Puerto Rico  Female          Fair                30.0
# 437221  Virgin Islands  Female     Very good                 8.0
# 437439  Virgin Islands  Female          Fair                 0.0
# 437449  Virgin Islands  Female     Very good                 0.0
#
#         MentalHealthDays   LastCheckupTime PhysicalActivities  SleepHours  \
# 49                   0.0  Within past year                Yes         7.0
# 707                  7.0  Within past year                Yes        12.0
# 794                 30.0  Within past year                 No         5.0
# 1135                 0.0  Within past year                Yes         6.0
# 3426                 0.0  Within past year                 No         6.0
# ...                  ...               ...                ...         ...
# 435171               0.0  Within past year                 No         4.0
# 435574               0.0  Within past year                Yes         NaN
# 437221               4.0  Within past year                Yes         5.0
# 437439               0.0  Within past year                Yes         7.0
# 437449               0.0  Within past year                Yes         7.0
#
#        HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms    BMI  \
# 49                 No       Yes  ...           1.60             34.47  13.46
# 707                No        No  ...           1.50             36.29  16.16
# 794               Yes        No  ...            NaN             34.93    NaN
# 1135               No        No  ...           1.68             31.75    NaN
# 3426               No        No  ...           1.55             38.56  16.06
# ...               ...       ...  ...            ...               ...    ...
# 435171             No        No  ...           1.57             36.74  14.81
# 435574             No        No  ...            NaN             39.92    NaN
# 437221             No        No  ...           1.60             35.38  13.82
# 437439            Yes       NaN  ...           1.35             36.29  20.02
# 437449             No        No  ...           1.47             37.65  17.35
#
#        AlcoholDrinkers HIVTesting FluVaxLast12 PneumoVaxEver  \
# 49                  No        Yes           No           Yes
# 707                 No         No           No            No
# 794                NaN        NaN          NaN           NaN
# 1135                No         No           No            No
# 3426                No         No          Yes           NaN
# ...                ...        ...          ...           ...
# 435171              No         No          Yes            No
# 435574              No        Yes           No           NaN
# 437221             NaN        NaN          NaN           NaN
# 437439              No         No           No            No
# 437449             Yes         No           No           Yes
#
#          TetanusLast10Tdap HighRiskLastYear CovidPos
# 49                     NaN               No       No
# 707     Yes, type not sure               No       No
# 794                    NaN              NaN      NaN
# 1135                    No               No       No
# 3426                   Yes               No       No
# ...                    ...              ...      ...
# 435171                 NaN               No       No
# 435574                  No               No       No
# 437221                 NaN              NaN      NaN
# 437439                  No               No       No
# 437449  Yes, type not sure               No       No
#
# [592 rows x 39 columns]

# %%
heart_data[heart_data['WeightInKilograms'] > 200]
# Out:
#             State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 3098      Alabama  Female          Fair                 0.0              30.0
# 5869       Alaska  Female          Fair                30.0               3.0
# 7263       Alaska    Male          Fair                 5.0              10.0
# 7844       Alaska    Male          Fair                 2.0              10.0
# 12026     Arizona  Female     Very good                 0.0               2.0
# ...           ...     ...           ...                 ...               ...
# 423463  Wisconsin    Male          Good                 0.0               0.0
# 426580    Wyoming  Female     Very good                 0.0               0.0
# 427841    Wyoming    Male     Very good                 1.0              30.0
# 429194       Guam    Male     Very good                 0.0              30.0
# 429751       Guam    Male          Good                30.0               0.0
#
#             LastCheckupTime PhysicalActivities  SleepHours HadHeartAttack  \
# 3098       Within past year                 No         6.0             No
# 5869    Within past 2 years                Yes         6.0             No
# 7263    Within past 2 years                 No         7.0             No
# 7844       Within past year                 No         7.0             No
# 12026      Within past year                Yes         7.0             No
# ...                     ...                ...         ...            ...
# 423463  Within past 2 years                Yes         6.0             No
# 426580     Within past year                Yes         8.0             No
# 427841     Within past year                Yes         4.0             No
# 429194     Within past year                 No         4.0             No
# 429751     Within past year                Yes         6.0            Yes
#
#        HadAngina  ... HeightInMeters WeightInKilograms    BMI AlcoholDrinkers  \
# 3098          No  ...           1.83            204.12  61.03              No
# 5869          No  ...           1.80            281.00  86.40              No
# 7263          No  ...           1.80            206.38  63.46              No
# 7844          No  ...           1.78            249.48  78.92             Yes
# 12026         No  ...           1.65            250.00  91.72             Yes
# ...          ...  ...            ...               ...    ...             ...
# 423463        No  ...           1.98            204.12  52.00              No
# 426580        No  ...           1.88            290.30  82.17             NaN
# 427841        No  ...           1.96            204.12  53.36              No
# 429194        No  ...           1.83            204.12  61.03             Yes
# 429751       Yes  ...            NaN            210.47    NaN              No
#
#        HIVTesting FluVaxLast12 PneumoVaxEver   TetanusLast10Tdap  \
# 3098          Yes           No            No                 Yes
# 5869           No           No            No                 NaN
# 7263          Yes          Yes            No                  No
# 7844          Yes          Yes            No                 Yes
# 12026         Yes           No           Yes  Yes, type not sure
# ...           ...          ...           ...                 ...
# 423463        NaN           No            No  Yes, type not sure
# 426580        NaN          NaN           NaN                 NaN
# 427841         No           No            No  Yes, type not sure
# 429194         No          Yes            No       Yes, not Tdap
# 429751         No          Yes           Yes                 Yes
#
#        HighRiskLastYear CovidPos
# 3098                Yes       No
# 5869                 No       No
# 7263                 No       No
# 7844                 No       No
# 12026                No       No
# ...                 ...      ...
# 423463              NaN      NaN
# 426580              NaN      NaN
# 427841               No      Yes
# 429194               No       No
# 429751               No       No
#
# [269 rows x 39 columns]

# %% [markdown]
# - Dropping rows with outlier values in WeightInKilograms as data seems incorrect.

# %%
heart_data.shape
# Out:
# (437462, 39)

# %%
# Dropping records with weight less than 40 kg
heart_data = heart_data.drop(heart_data[heart_data['WeightInKilograms'] < 40].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (436870, 39)

# %%
# Dropping records with weight greater than 200 kg
heart_data = heart_data.drop(heart_data[heart_data['WeightInKilograms'] > 200].index)
heart_data.reset_index(drop=True, inplace=True)
heart_data.shape
# Out:
# (436601, 39)

# %%
sns.boxplot(data=heart_data, x='WeightInKilograms')
# Out:
# <Axes: xlabel='WeightInKilograms'>

# %% [markdown]
# # Insights from Data

# %% [markdown]
# - Now that the data has been cleaned and prepared, free from any unusual values, and it's ready for analysis. We can start exploring the data to uncover important insights that will help answer our questions.
